# %%
import time
import numpy as np
import tensorflow as tf
import re
from collections import Counter
from time import sleep
import json
import random

# %%
with open('data/pos_train.json') as json_data:
    d = json.load(json_data)

text=[]
l=0

for i in d:
    for j in i:
        for k in j:
            text.append(k)

tt = []
for i in range(len(text)):
    if(text[i]!=''):
        tt.append(text[i])

text = tt

for i in range(len(text)):
    if(text[i]=='$'or text[i]=='PDT' or text[i]=='WP$' or text[i]=="SYM" or text[i]=='LS' or text[i]=='#' or text[i]=='UH'):
        text[i]='OTHER'
    

word_counts = Counter(text)

word_counts.most_common()
# Out:
# [('NN', 391092),
#  ('IN', 313428),
#  ('NNP', 286327),
#  ('DT', 246818),
#  ('JJ', 194522),
#  ('NNS', 150057),
#  (',', 138811),
#  ('.', 92716),
#  ('CC', 86433),
#  ('VBD', 83807),
#  ('CD', 77651),
#  ('RB', 71899),
#  ('VBN', 69596),
#  ('TO', 48800),
#  ('VBZ', 41862),
#  ('VB', 40118),
#  ('VBG', 35283),
#  (':', 34343),
#  ('VBP', 28324),
#  ('PRP', 24380),
#  ('FW', 22213),
#  ('PRP$', 18771),
#  ('POS', 14923),
#  ('WDT', 13756),
#  ("''", 13344),
#  ('``', 12561),
#  ('MD', 11441),
#  ('NNPS', 10637),
#  ('JJS', 6400),
#  ('JJR', 6373),
#  ('WRB', 5119),
#  ('WP', 4378),
#  ('RP', 3189),
#  ('RBR', 2910),
#  ('OTHER', 2645),
#  ('EX', 2623),
#  ('RBS', 2274)]

# %%
def create_lookup_tables(words):
    """
    Create lookup tables for vocabulary
    :param words: Input list of words
    :return: A tuple of dicts.  The first dict....
    """
    word_counts = Counter(words)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {ii: word for ii, word in enumerate(sorted_vocab)}
    vocab_to_int = {word: ii for ii, word in int_to_vocab.items()}

    return vocab_to_int, int_to_vocab

def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)


def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
words = text

print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))

# vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
vocab_to_int, int_to_vocab = create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

word_counts = Counter(int_words)
total_count = len(int_words)
weights = [1 - 4*count/total_count for word, count in word_counts.items()]
# Out:
# Total words: 2609824
# Unique words: 37

# %%
def get_train_word():
    threshold = random.uniform(0.08, 0.1)
    word_counts = Counter(int_words)
    total_count = len(int_words)
    freqs = {word: count/total_count for word, count in word_counts.items()}
    p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
    train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]
    return train_words, threshold

# %%
batch_size = 1000
window_size = 5
n_vocab = len(int_to_vocab)
n_embedding =  50
starter_learning_rate = 0.0001
decay_steps = 2000
decay_rate = 0.96
lambda_l2 = 0.01

# %%
with tf.device('/device:GPU:3'):

    train_graph = tf.Graph()
    with train_graph.as_default():
        inputs = tf.placeholder(tf.int32, [None], name='inputs')
        labels = tf.placeholder(tf.int32, [None], name='labels')

        embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
        embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output
        embed_drop = tf.nn.dropout(embed, 0.8)

        softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding)), name="softmax_w") # create softmax weight matrix here
        softmax_b = tf.Variable(tf.zeros(n_vocab), name="softmax_bias") # create softmax biases here

        logits = tf.matmul(embed_drop, tf.transpose(softmax_w)) + softmax_b
        
        class_weight = tf.constant(weights)
        weighted_logits = logits * class_weight


        
        labels_one_hot = tf.one_hot(labels, n_vocab)
        
        tv_all = tf.trainable_variables()

        l2_loss = lambda_l2 * tf.reduce_sum([ tf.nn.l2_loss(v) for v in tv_all ])

        loss = tf.nn.softmax_cross_entropy_with_logits(labels=labels_one_hot, logits=weighted_logits)
        
        cost = tf.reduce_mean(loss) + l2_loss
        
        global_step = tf.Variable(0, trainable=False, name="global_step")

        learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, decay_steps, decay_rate)


        optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost, global_step=global_step)
        
        norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
        normalized_embedding = embedding / norm

# %%
model_name = 'pos_weighted_2'

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints/pos_weighted_2

# %%
epochs = 20

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    batch_loss = 0
    sess.run(tf.global_variables_initializer())
    
#     saver.restore(sess, tf.train.latest_checkpoint('checkpoints/pos'))
#     embed_mat = sess.run(embedding)
    
    for e in range(1, epochs+1):
        train_words, threshold = get_train_word()
        print("Epoch {}/{}".format(e, epochs), "Threshold: {}".format(threshold), "Length of Training words: {}".format(len(train_words)))
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            feed = {inputs: x,
                    labels: np.array(y)}
            global_steps, train_loss, _ = sess.run([global_step, cost, optimizer], feed_dict=feed)
            
            batch_loss += train_loss
            
            if iteration % 100== 0: 
                end = time.time()
                print("Global Step: {}".format(global_steps), "Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(batch_loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                batch_loss = 0
                start = time.time()
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/" + model_name + "/pos.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/20 Threshold: 0.09139197041239562 Length of Training words: 2454481
# Global Step: 100 Epoch 1/20 Iteration: 100 Avg. Training loss: 19.3128 0.0060 sec/batch
# Global Step: 200 Epoch 1/20 Iteration: 200 Avg. Training loss: 18.8140 0.0067 sec/batch
# Global Step: 300 Epoch 1/20 Iteration: 300 Avg. Training loss: 18.2805 0.0061 sec/batch
# Global Step: 400 Epoch 1/20 Iteration: 400 Avg. Training loss: 17.7710 0.0060 sec/batch
# Global Step: 500 Epoch 1/20 Iteration: 500 Avg. Training loss: 17.3132 0.0056 sec/batch
# Global Step: 600 Epoch 1/20 Iteration: 600 Avg. Training loss: 16.8837 0.0056 sec/batch
# Global Step: 700 Epoch 1/20 Iteration: 700 Avg. Training loss: 16.4681 0.0055 sec/batch
# Global Step: 800 Epoch 1/20 Iteration: 800 Avg. Training loss: 16.0938 0.0065 sec/batch
# Global Step: 900 Epoch 1/20 Iteration: 900 Avg. Training loss: 15.7270 0.0059 sec/batch
# Global Step: 1000 Epoch 1/20 Iteration: 1000 Avg. Training loss: 15.3975 0.0065 sec/batch
# Global Step: 1100 Epoch 1/20 Iteration: 1100 Avg. Training loss: 15.0260 0.0060 sec/batch
# Global Step: 1200 Epoch 1/20 Iteration: 1200 Avg. Training loss: 14.6796 0.0071 sec/batch
# Global Step: 1300 Epoch 1/20 Iteration: 1300 Avg. Training loss: 14.3952 0.0059 sec/batch
# Global Step: 1400 Epoch 1/20 Iteration: 1400 Avg. Training loss: 14.1125 0.0058 sec/batch
# Global Step: 1500 Epoch 1/20 Iteration: 1500 Avg. Training loss: 13.8105 0.0063 sec/batch
# Global Step: 1600 Epoch 1/20 Iteration: 1600 Avg. Training loss: 13.5255 0.0058 sec/batch
# Global Step: 1700 Epoch 1/20 Iteration: 1700 Avg. Training loss: 13.2526 0.0059 sec/batch
# Global Step: 1800 Epoch 1/20 Iteration: 1800 Avg. Training loss: 13.0403 0.0082 sec/batch
# Global Step: 1900 Epoch 1/20 Iteration: 1900 Avg. Training loss: 12.7783 0.0069 sec/batch
# Global Step: 2000 Epoch 1/20 Iteration: 2000 Avg. Training loss: 12.5375 0.0065 sec/batch
# Global Step: 2100 Epoch 1/20 Iteration: 2100 Avg. Training loss: 12.3061 0.0057 sec/batch
# Global Step: 2200 Epoch 1/20 Iteration: 2200 Avg. Training loss: 12.0679 0.0091 sec/batch
# Global Step: 2300 Epoch 1/20 Iteration: 2300 Avg. Training loss: 11.8690 0.0083 sec/batch
# Global Step: 2400 Epoch 1/20 Iteration: 2400 Avg. Training loss: 11.6642 0.0099 sec/batch
# Epoch 2/20 Threshold: 0.08823158434729128 Length of Training words: 2436082
# Global Step: 2500 Epoch 2/20 Iteration: 2500 Avg. Training loss: 11.4612 0.0034 sec/batch
# Global Step: 2600 Epoch 2/20 Iteration: 2600 Avg. Training loss: 11.2763 0.0080 sec/batch
# Global Step: 2700 Epoch 2/20 Iteration: 2700 Avg. Training loss: 11.0971 0.0075 sec/batch
# Global Step: 2800 Epoch 2/20 Iteration: 2800 Avg. Training loss: 10.8903 0.0057 sec/batch
# Global Step: 2900 Epoch 2/20 Iteration: 2900 Avg. Training loss: 10.6960 0.0083 sec/batch
# Global Step: 3000 Epoch 2/20 Iteration: 3000 Avg. Training loss: 10.5243 0.0055 sec/batch
# Global Step: 3100 Epoch 2/20 Iteration: 3100 Avg. Training loss: 10.3622 0.0056 sec/batch
# Global Step: 3200 Epoch 2/20 Iteration: 3200 Avg. Training loss: 10.1971 0.0064 sec/batch
# Global Step: 3300 Epoch 2/20 Iteration: 3300 Avg. Training loss: 10.0372 0.0060 sec/batch
# Global Step: 3400 Epoch 2/20 Iteration: 3400 Avg. Training loss: 9.8953 0.0063 sec/batch
# Global Step: 3500 Epoch 2/20 Iteration: 3500 Avg. Training loss: 9.7198 0.0064 sec/batch
# Global Step: 3600 Epoch 2/20 Iteration: 3600 Avg. Training loss: 9.5567 0.0071 sec/batch
# Global Step: 3700 Epoch 2/20 Iteration: 3700 Avg. Training loss: 9.4310 0.0063 sec/batch
# Global Step: 3800 Epoch 2/20 Iteration: 3800 Avg. Training loss: 9.2825 0.0062 sec/batch
# Global Step: 3900 Epoch 2/20 Iteration: 3900 Avg. Training loss: 9.1474 0.0080 sec/batch
# Global Step: 4000 Epoch 2/20 Iteration: 4000 Avg. Training loss: 9.0110 0.0062 sec/batch
# Global Step: 4100 Epoch 2/20 Iteration: 4100 Avg. Training loss: 8.8706 0.0082 sec/batch
# Global Step: 4200 Epoch 2/20 Iteration: 4200 Avg. Training loss: 8.7514 0.0056 sec/batch
# Global Step: 4300 Epoch 2/20 Iteration: 4300 Avg. Training loss: 8.6469 0.0054 sec/batch
# Global Step: 4400 Epoch 2/20 Iteration: 4400 Avg. Training loss: 8.4993 0.0057 sec/batch
# Global Step: 4500 Epoch 2/20 Iteration: 4500 Avg. Training loss: 8.3873 0.0056 sec/batch
# Global Step: 4600 Epoch 2/20 Iteration: 4600 Avg. Training loss: 8.2503 0.0076 sec/batch
# Global Step: 4700 Epoch 2/20 Iteration: 4700 Avg. Training loss: 8.1316 0.0064 sec/batch
# Global Step: 4800 Epoch 2/20 Iteration: 4800 Avg. Training loss: 8.0291 0.0057 sec/batch
# Epoch 3/20 Threshold: 0.08798410121174571 Length of Training words: 2434685
# Global Step: 4900 Epoch 3/20 Iteration: 4900 Avg. Training loss: 7.9179 0.0010 sec/batch
# Global Step: 5000 Epoch 3/20 Iteration: 5000 Avg. Training loss: 7.8397 0.0063 sec/batch
# Global Step: 5100 Epoch 3/20 Iteration: 5100 Avg. Training loss: 7.7368 0.0071 sec/batch
# Global Step: 5200 Epoch 3/20 Iteration: 5200 Avg. Training loss: 7.6187 0.0071 sec/batch
# Global Step: 5300 Epoch 3/20 Iteration: 5300 Avg. Training loss: 7.4968 0.0057 sec/batch
# Global Step: 5400 Epoch 3/20 Iteration: 5400 Avg. Training loss: 7.4087 0.0059 sec/batch
# Global Step: 5500 Epoch 3/20 Iteration: 5500 Avg. Training loss: 7.3141 0.0072 sec/batch
# Global Step: 5600 Epoch 3/20 Iteration: 5600 Avg. Training loss: 7.2181 0.0064 sec/batch
# Global Step: 5700 Epoch 3/20 Iteration: 5700 Avg. Training loss: 7.1436 0.0081 sec/batch
# Global Step: 5800 Epoch 3/20 Iteration: 5800 Avg. Training loss: 7.0376 0.0058 sec/batch
# Global Step: 5900 Epoch 3/20 Iteration: 5900 Avg. Training loss: 6.9512 0.0059 sec/batch
# Global Step: 6000 Epoch 3/20 Iteration: 6000 Avg. Training loss: 6.8549 0.0065 sec/batch
# Global Step: 6100 Epoch 3/20 Iteration: 6100 Avg. Training loss: 6.7793 0.0066 sec/batch
# Global Step: 6200 Epoch 3/20 Iteration: 6200 Avg. Training loss: 6.6881 0.0060 sec/batch
# Global Step: 6300 Epoch 3/20 Iteration: 6300 Avg. Training loss: 6.6254 0.0072 sec/batch
# Global Step: 6400 Epoch 3/20 Iteration: 6400 Avg. Training loss: 6.5389 0.0062 sec/batch
# Global Step: 6500 Epoch 3/20 Iteration: 6500 Avg. Training loss: 6.4631 0.0059 sec/batch
# Global Step: 6600 Epoch 3/20 Iteration: 6600 Avg. Training loss: 6.3753 0.0061 sec/batch
# Global Step: 6700 Epoch 3/20 Iteration: 6700 Avg. Training loss: 6.3335 0.0059 sec/batch
# Global Step: 6800 Epoch 3/20 Iteration: 6800 Avg. Training loss: 6.2411 0.0070 sec/batch
# Global Step: 6900 Epoch 3/20 Iteration: 6900 Avg. Training loss: 6.1803 0.0061 sec/batch
# Global Step: 7000 Epoch 3/20 Iteration: 7000 Avg. Training loss: 6.0887 0.0057 sec/batch
# Global Step: 7100 Epoch 3/20 Iteration: 7100 Avg. Training loss: 6.0157 0.0057 sec/batch
# Global Step: 7200 Epoch 3/20 Iteration: 7200 Avg. Training loss: 5.9744 0.0078 sec/batch
# Global Step: 7300 Epoch 3/20 Iteration: 7300 Avg. Training loss: 5.8939 0.0068 sec/batch
# Epoch 4/20 Threshold: 0.09776896069229687 Length of Training words: 2487508
# Global Step: 7400 Epoch 4/20 Iteration: 7400 Avg. Training loss: 5.8438 0.0043 sec/batch
# Global Step: 7500 Epoch 4/20 Iteration: 7500 Avg. Training loss: 5.7850 0.0059 sec/batch
# Global Step: 7600 Epoch 4/20 Iteration: 7600 Avg. Training loss: 5.7264 0.0063 sec/batch
# Global Step: 7700 Epoch 4/20 Iteration: 7700 Avg. Training loss: 5.6480 0.0056 sec/batch
# Global Step: 7800 Epoch 4/20 Iteration: 7800 Avg. Training loss: 5.5859 0.0059 sec/batch
# Global Step: 7900 Epoch 4/20 Iteration: 7900 Avg. Training loss: 5.5241 0.0058 sec/batch
# Global Step: 8000 Epoch 4/20 Iteration: 8000 Avg. Training loss: 5.4942 0.0058 sec/batch
# Global Step: 8100 Epoch 4/20 Iteration: 8100 Avg. Training loss: 5.4303 0.0057 sec/batch
# Global Step: 8200 Epoch 4/20 Iteration: 8200 Avg. Training loss: 5.3661 0.0066 sec/batch
# Global Step: 8300 Epoch 4/20 Iteration: 8300 Avg. Training loss: 5.3431 0.0063 sec/batch
# Global Step: 8400 Epoch 4/20 Iteration: 8400 Avg. Training loss: 5.2587 0.0074 sec/batch
# Global Step: 8500 Epoch 4/20 Iteration: 8500 Avg. Training loss: 5.2085 0.0059 sec/batch
# Global Step: 8600 Epoch 4/20 Iteration: 8600 Avg. Training loss: 5.1815 0.0065 sec/batch
# Global Step: 8700 Epoch 4/20 Iteration: 8700 Avg. Training loss: 5.1236 0.0068 sec/batch
# Global Step: 8800 Epoch 4/20 Iteration: 8800 Avg. Training loss: 5.0833 0.0061 sec/batch
# Global Step: 8900 Epoch 4/20 Iteration: 8900 Avg. Training loss: 5.0411 0.0062 sec/batch
# Global Step: 9000 Epoch 4/20 Iteration: 9000 Avg. Training loss: 4.9888 0.0061 sec/batch
# Global Step: 9100 Epoch 4/20 Iteration: 9100 Avg. Training loss: 4.9487 0.0062 sec/batch
# Global Step: 9200 Epoch 4/20 Iteration: 9200 Avg. Training loss: 4.9306 0.0064 sec/batch
# Global Step: 9300 Epoch 4/20 Iteration: 9300 Avg. Training loss: 4.8697 0.0082 sec/batch
# Global Step: 9400 Epoch 4/20 Iteration: 9400 Avg. Training loss: 4.8397 0.0067 sec/batch
# Global Step: 9500 Epoch 4/20 Iteration: 9500 Avg. Training loss: 4.7778 0.0083 sec/batch
# Global Step: 9600 Epoch 4/20 Iteration: 9600 Avg. Training loss: 4.7356 0.0059 sec/batch
# Global Step: 9700 Epoch 4/20 Iteration: 9700 Avg. Training loss: 4.7125 0.0056 sec/batch
# Global Step: 9800 Epoch 4/20 Iteration: 9800 Avg. Training loss: 4.6782 0.0062 sec/batch
# Epoch 5/20 Threshold: 0.08901550031659605 Length of Training words: 2440650
# Global Step: 9900 Epoch 5/20 Iteration: 9900 Avg. Training loss: 4.6574 0.0084 sec/batch
# Global Step: 10000 Epoch 5/20 Iteration: 10000 Avg. Training loss: 4.6412 0.0080 sec/batch
# Global Step: 10100 Epoch 5/20 Iteration: 10100 Avg. Training loss: 4.5975 0.0058 sec/batch
# Global Step: 10200 Epoch 5/20 Iteration: 10200 Avg. Training loss: 4.5508 0.0059 sec/batch
# Global Step: 10300 Epoch 5/20 Iteration: 10300 Avg. Training loss: 4.5135 0.0060 sec/batch
# Global Step: 10400 Epoch 5/20 Iteration: 10400 Avg. Training loss: 4.4858 0.0083 sec/batch
# Global Step: 10500 Epoch 5/20 Iteration: 10500 Avg. Training loss: 4.4591 0.0057 sec/batch
# Global Step: 10600 Epoch 5/20 Iteration: 10600 Avg. Training loss: 4.4353 0.0077 sec/batch
# Global Step: 10700 Epoch 5/20 Iteration: 10700 Avg. Training loss: 4.3993 0.0061 sec/batch
# Global Step: 10800 Epoch 5/20 Iteration: 10800 Avg. Training loss: 4.3712 0.0072 sec/batch
# Global Step: 10900 Epoch 5/20 Iteration: 10900 Avg. Training loss: 4.3334 0.0065 sec/batch
# Global Step: 11000 Epoch 5/20 Iteration: 11000 Avg. Training loss: 4.3117 0.0062 sec/batch
# Global Step: 11100 Epoch 5/20 Iteration: 11100 Avg. Training loss: 4.2905 0.0076 sec/batch
# Global Step: 11200 Epoch 5/20 Iteration: 11200 Avg. Training loss: 4.2631 0.0082 sec/batch
# Global Step: 11300 Epoch 5/20 Iteration: 11300 Avg. Training loss: 4.2441 0.0094 sec/batch
# Global Step: 11400 Epoch 5/20 Iteration: 11400 Avg. Training loss: 4.2080 0.0092 sec/batch
# Global Step: 11500 Epoch 5/20 Iteration: 11500 Avg. Training loss: 4.1796 0.0084 sec/batch
# Global Step: 11600 Epoch 5/20 Iteration: 11600 Avg. Training loss: 4.1868 0.0072 sec/batch
# Global Step: 11700 Epoch 5/20 Iteration: 11700 Avg. Training loss: 4.1470 0.0077 sec/batch
# Global Step: 11800 Epoch 5/20 Iteration: 11800 Avg. Training loss: 4.1321 0.0069 sec/batch
# Global Step: 11900 Epoch 5/20 Iteration: 11900 Avg. Training loss: 4.0953 0.0058 sec/batch
# Global Step: 12000 Epoch 5/20 Iteration: 12000 Avg. Training loss: 4.0700 0.0074 sec/batch
# Global Step: 12100 Epoch 5/20 Iteration: 12100 Avg. Training loss: 4.0549 0.0063 sec/batch
# Global Step: 12200 Epoch 5/20 Iteration: 12200 Avg. Training loss: 4.0345 0.0062 sec/batch
# Epoch 6/20 Threshold: 0.08109457081109255 Length of Training words: 2392493
# Global Step: 12300 Epoch 6/20 Iteration: 12300 Avg. Training loss: 4.0235 0.0033 sec/batch
# Global Step: 12400 Epoch 6/20 Iteration: 12400 Avg. Training loss: 4.0246 0.0088 sec/batch
# Global Step: 12500 Epoch 6/20 Iteration: 12500 Avg. Training loss: 4.0034 0.0062 sec/batch
# Global Step: 12600 Epoch 6/20 Iteration: 12600 Avg. Training loss: 3.9785 0.0082 sec/batch
# Global Step: 12700 Epoch 6/20 Iteration: 12700 Avg. Training loss: 3.9498 0.0068 sec/batch
# Global Step: 12800 Epoch 6/20 Iteration: 12800 Avg. Training loss: 3.9227 0.0060 sec/batch
# Global Step: 12900 Epoch 6/20 Iteration: 12900 Avg. Training loss: 3.9320 0.0060 sec/batch
# Global Step: 13000 Epoch 6/20 Iteration: 13000 Avg. Training loss: 3.9040 0.0063 sec/batch
# Global Step: 13100 Epoch 6/20 Iteration: 13100 Avg. Training loss: 3.8803 0.0064 sec/batch
# Global Step: 13200 Epoch 6/20 Iteration: 13200 Avg. Training loss: 3.8842 0.0061 sec/batch
# Global Step: 13300 Epoch 6/20 Iteration: 13300 Avg. Training loss: 3.8444 0.0058 sec/batch
# Global Step: 13400 Epoch 6/20 Iteration: 13400 Avg. Training loss: 3.8356 0.0058 sec/batch
# Global Step: 13500 Epoch 6/20 Iteration: 13500 Avg. Training loss: 3.8308 0.0088 sec/batch
# Global Step: 13600 Epoch 6/20 Iteration: 13600 Avg. Training loss: 3.8028 0.0062 sec/batch
# Global Step: 13700 Epoch 6/20 Iteration: 13700 Avg. Training loss: 3.8050 0.0081 sec/batch
# Global Step: 13800 Epoch 6/20 Iteration: 13800 Avg. Training loss: 3.7817 0.0067 sec/batch
# Global Step: 13900 Epoch 6/20 Iteration: 13900 Avg. Training loss: 3.7571 0.0057 sec/batch
# Global Step: 14000 Epoch 6/20 Iteration: 14000 Avg. Training loss: 3.7754 0.0074 sec/batch
# Global Step: 14100 Epoch 6/20 Iteration: 14100 Avg. Training loss: 3.7474 0.0066 sec/batch
# Global Step: 14200 Epoch 6/20 Iteration: 14200 Avg. Training loss: 3.7427 0.0057 sec/batch
# Global Step: 14300 Epoch 6/20 Iteration: 14300 Avg. Training loss: 3.7166 0.0071 sec/batch
# Global Step: 14400 Epoch 6/20 Iteration: 14400 Avg. Training loss: 3.6963 0.0059 sec/batch
# Global Step: 14500 Epoch 6/20 Iteration: 14500 Avg. Training loss: 3.6981 0.0060 sec/batch
# Global Step: 14600 Epoch 6/20 Iteration: 14600 Avg. Training loss: 3.6775 0.0072 sec/batch
# Epoch 7/20 Threshold: 0.08005491537118235 Length of Training words: 2385365
# Global Step: 14700 Epoch 7/20 Iteration: 14700 Avg. Training loss: 3.6758 0.0037 sec/batch
# Global Step: 14800 Epoch 7/20 Iteration: 14800 Avg. Training loss: 3.6822 0.0074 sec/batch
# Global Step: 14900 Epoch 7/20 Iteration: 14900 Avg. Training loss: 3.6690 0.0063 sec/batch
# Global Step: 15000 Epoch 7/20 Iteration: 15000 Avg. Training loss: 3.6486 0.0084 sec/batch
# Global Step: 15100 Epoch 7/20 Iteration: 15100 Avg. Training loss: 3.6310 0.0064 sec/batch
# Global Step: 15200 Epoch 7/20 Iteration: 15200 Avg. Training loss: 3.6183 0.0056 sec/batch
# Global Step: 15300 Epoch 7/20 Iteration: 15300 Avg. Training loss: 3.6223 0.0065 sec/batch
# Global Step: 15400 Epoch 7/20 Iteration: 15400 Avg. Training loss: 3.6092 0.0063 sec/batch
# Global Step: 15500 Epoch 7/20 Iteration: 15500 Avg. Training loss: 3.5960 0.0062 sec/batch
# Global Step: 15600 Epoch 7/20 Iteration: 15600 Avg. Training loss: 3.5934 0.0062 sec/batch
# Global Step: 15700 Epoch 7/20 Iteration: 15700 Avg. Training loss: 3.5706 0.0058 sec/batch
# Global Step: 15800 Epoch 7/20 Iteration: 15800 Avg. Training loss: 3.5657 0.0066 sec/batch
# Global Step: 15900 Epoch 7/20 Iteration: 15900 Avg. Training loss: 3.5657 0.0084 sec/batch
# Global Step: 16000 Epoch 7/20 Iteration: 16000 Avg. Training loss: 3.5528 0.0065 sec/batch
# Global Step: 16100 Epoch 7/20 Iteration: 16100 Avg. Training loss: 3.5520 0.0058 sec/batch
# Global Step: 16200 Epoch 7/20 Iteration: 16200 Avg. Training loss: 3.5321 0.0060 sec/batch
# Global Step: 16300 Epoch 7/20 Iteration: 16300 Avg. Training loss: 3.5219 0.0060 sec/batch
# Global Step: 16400 Epoch 7/20 Iteration: 16400 Avg. Training loss: 3.5394 0.0057 sec/batch
# Global Step: 16500 Epoch 7/20 Iteration: 16500 Avg. Training loss: 3.5226 0.0055 sec/batch
# Global Step: 16600 Epoch 7/20 Iteration: 16600 Avg. Training loss: 3.5245 0.0058 sec/batch
# Global Step: 16700 Epoch 7/20 Iteration: 16700 Avg. Training loss: 3.4952 0.0056 sec/batch
# Global Step: 16800 Epoch 7/20 Iteration: 16800 Avg. Training loss: 3.4796 0.0064 sec/batch
# Global Step: 16900 Epoch 7/20 Iteration: 16900 Avg. Training loss: 3.4941 0.0058 sec/batch
# Global Step: 17000 Epoch 7/20 Iteration: 17000 Avg. Training loss: 3.4770 0.0074 sec/batch
# Epoch 8/20 Threshold: 0.09897009058952216 Length of Training words: 2493305
# Global Step: 17100 Epoch 8/20 Iteration: 17100 Avg. Training loss: 3.4730 0.0094 sec/batch
# Global Step: 17200 Epoch 8/20 Iteration: 17200 Avg. Training loss: 3.4672 0.0062 sec/batch
# Global Step: 17300 Epoch 8/20 Iteration: 17300 Avg. Training loss: 3.4666 0.0056 sec/batch
# Global Step: 17400 Epoch 8/20 Iteration: 17400 Avg. Training loss: 3.4459 0.0059 sec/batch
# Global Step: 17500 Epoch 8/20 Iteration: 17500 Avg. Training loss: 3.4338 0.0064 sec/batch
# Global Step: 17600 Epoch 8/20 Iteration: 17600 Avg. Training loss: 3.4195 0.0057 sec/batch
# Global Step: 17700 Epoch 8/20 Iteration: 17700 Avg. Training loss: 3.4381 0.0056 sec/batch
# Global Step: 17800 Epoch 8/20 Iteration: 17800 Avg. Training loss: 3.4263 0.0056 sec/batch
# Global Step: 17900 Epoch 8/20 Iteration: 17900 Avg. Training loss: 3.4090 0.0062 sec/batch
# Global Step: 18000 Epoch 8/20 Iteration: 18000 Avg. Training loss: 3.4285 0.0083 sec/batch
# Global Step: 18100 Epoch 8/20 Iteration: 18100 Avg. Training loss: 3.3963 0.0065 sec/batch
# Global Step: 18200 Epoch 8/20 Iteration: 18200 Avg. Training loss: 3.3877 0.0070 sec/batch
# Global Step: 18300 Epoch 8/20 Iteration: 18300 Avg. Training loss: 3.4029 0.0059 sec/batch
# Global Step: 18400 Epoch 8/20 Iteration: 18400 Avg. Training loss: 3.3913 0.0059 sec/batch
# Global Step: 18500 Epoch 8/20 Iteration: 18500 Avg. Training loss: 3.3861 0.0057 sec/batch
# Global Step: 18600 Epoch 8/20 Iteration: 18600 Avg. Training loss: 3.3876 0.0062 sec/batch
# Global Step: 18700 Epoch 8/20 Iteration: 18700 Avg. Training loss: 3.3803 0.0058 sec/batch
# Global Step: 18800 Epoch 8/20 Iteration: 18800 Avg. Training loss: 3.3757 0.0061 sec/batch
# Global Step: 18900 Epoch 8/20 Iteration: 18900 Avg. Training loss: 3.3881 0.0058 sec/batch
# Global Step: 19000 Epoch 8/20 Iteration: 19000 Avg. Training loss: 3.3710 0.0055 sec/batch
# Global Step: 19100 Epoch 8/20 Iteration: 19100 Avg. Training loss: 3.3699 0.0063 sec/batch
# Global Step: 19200 Epoch 8/20 Iteration: 19200 Avg. Training loss: 3.3513 0.0083 sec/batch
# Global Step: 19300 Epoch 8/20 Iteration: 19300 Avg. Training loss: 3.3389 0.0075 sec/batch
# Global Step: 19400 Epoch 8/20 Iteration: 19400 Avg. Training loss: 3.3586 0.0072 sec/batch
# Global Step: 19500 Epoch 8/20 Iteration: 19500 Avg. Training loss: 3.3433 0.0055 sec/batch
# Epoch 9/20 Threshold: 0.09746089706358427 Length of Training words: 2486226
# Global Step: 19600 Epoch 9/20 Iteration: 19600 Avg. Training loss: 3.3562 0.0059 sec/batch
# Global Step: 19700 Epoch 9/20 Iteration: 19700 Avg. Training loss: 3.3625 0.0063 sec/batch
# Global Step: 19800 Epoch 9/20 Iteration: 19800 Avg. Training loss: 3.3578 0.0092 sec/batch
# Global Step: 19900 Epoch 9/20 Iteration: 19900 Avg. Training loss: 3.3398 0.0060 sec/batch
# Global Step: 20000 Epoch 9/20 Iteration: 20000 Avg. Training loss: 3.3326 0.0058 sec/batch
# Global Step: 20100 Epoch 9/20 Iteration: 20100 Avg. Training loss: 3.3269 0.0059 sec/batch
# Global Step: 20200 Epoch 9/20 Iteration: 20200 Avg. Training loss: 3.3403 0.0064 sec/batch
# Global Step: 20300 Epoch 9/20 Iteration: 20300 Avg. Training loss: 3.3322 0.0061 sec/batch
# Global Step: 20400 Epoch 9/20 Iteration: 20400 Avg. Training loss: 3.3179 0.0064 sec/batch
# Global Step: 20500 Epoch 9/20 Iteration: 20500 Avg. Training loss: 3.3412 0.0061 sec/batch
# Global Step: 20600 Epoch 9/20 Iteration: 20600 Avg. Training loss: 3.3115 0.0061 sec/batch
# Global Step: 20700 Epoch 9/20 Iteration: 20700 Avg. Training loss: 3.3061 0.0075 sec/batch
# Global Step: 20800 Epoch 9/20 Iteration: 20800 Avg. Training loss: 3.3228 0.0070 sec/batch
# Global Step: 20900 Epoch 9/20 Iteration: 20900 Avg. Training loss: 3.3078 0.0066 sec/batch
# Global Step: 21000 Epoch 9/20 Iteration: 21000 Avg. Training loss: 3.3159 0.0059 sec/batch
# Global Step: 21100 Epoch 9/20 Iteration: 21100 Avg. Training loss: 3.3128 0.0055 sec/batch
# Global Step: 21200 Epoch 9/20 Iteration: 21200 Avg. Training loss: 3.3020 0.0058 sec/batch
# Global Step: 21300 Epoch 9/20 Iteration: 21300 Avg. Training loss: 3.3032 0.0065 sec/batch
# Global Step: 21400 Epoch 9/20 Iteration: 21400 Avg. Training loss: 3.3253 0.0083 sec/batch
# Global Step: 21500 Epoch 9/20 Iteration: 21500 Avg. Training loss: 3.3018 0.0067 sec/batch
# Global Step: 21600 Epoch 9/20 Iteration: 21600 Avg. Training loss: 3.3077 0.0067 sec/batch
# Global Step: 21700 Epoch 9/20 Iteration: 21700 Avg. Training loss: 3.2861 0.0060 sec/batch
# Global Step: 21800 Epoch 9/20 Iteration: 21800 Avg. Training loss: 3.2849 0.0074 sec/batch
# Global Step: 21900 Epoch 9/20 Iteration: 21900 Avg. Training loss: 3.2886 0.0059 sec/batch
# Global Step: 22000 Epoch 9/20 Iteration: 22000 Avg. Training loss: 3.2926 0.0066 sec/batch
# Epoch 10/20 Threshold: 0.0844398995626948 Length of Training words: 2413046
# Global Step: 22100 Epoch 10/20 Iteration: 22100 Avg. Training loss: 3.3068 0.0075 sec/batch
# Global Step: 22200 Epoch 10/20 Iteration: 22200 Avg. Training loss: 3.3317 0.0062 sec/batch
# Global Step: 22300 Epoch 10/20 Iteration: 22300 Avg. Training loss: 3.3102 0.0073 sec/batch
# Global Step: 22400 Epoch 10/20 Iteration: 22400 Avg. Training loss: 3.2998 0.0057 sec/batch
# Global Step: 22500 Epoch 10/20 Iteration: 22500 Avg. Training loss: 3.2948 0.0082 sec/batch
# Global Step: 22600 Epoch 10/20 Iteration: 22600 Avg. Training loss: 3.2939 0.0062 sec/batch
# Global Step: 22700 Epoch 10/20 Iteration: 22700 Avg. Training loss: 3.2977 0.0077 sec/batch
# Global Step: 22800 Epoch 10/20 Iteration: 22800 Avg. Training loss: 3.3036 0.0058 sec/batch
# Global Step: 22900 Epoch 10/20 Iteration: 22900 Avg. Training loss: 3.2921 0.0058 sec/batch
# Global Step: 23000 Epoch 10/20 Iteration: 23000 Avg. Training loss: 3.2937 0.0060 sec/batch
# Global Step: 23100 Epoch 10/20 Iteration: 23100 Avg. Training loss: 3.2772 0.0057 sec/batch
# Global Step: 23200 Epoch 10/20 Iteration: 23200 Avg. Training loss: 3.2897 0.0059 sec/batch
# Global Step: 23300 Epoch 10/20 Iteration: 23300 Avg. Training loss: 3.2859 0.0055 sec/batch
# Global Step: 23400 Epoch 10/20 Iteration: 23400 Avg. Training loss: 3.2946 0.0061 sec/batch
# Global Step: 23500 Epoch 10/20 Iteration: 23500 Avg. Training loss: 3.2881 0.0079 sec/batch
# Global Step: 23600 Epoch 10/20 Iteration: 23600 Avg. Training loss: 3.2880 0.0068 sec/batch
# Global Step: 23700 Epoch 10/20 Iteration: 23700 Avg. Training loss: 3.2736 0.0060 sec/batch
# Global Step: 23800 Epoch 10/20 Iteration: 23800 Avg. Training loss: 3.3020 0.0062 sec/batch
# Global Step: 23900 Epoch 10/20 Iteration: 23900 Avg. Training loss: 3.2857 0.0061 sec/batch
# Global Step: 24000 Epoch 10/20 Iteration: 24000 Avg. Training loss: 3.2924 0.0060 sec/batch
# Global Step: 24100 Epoch 10/20 Iteration: 24100 Avg. Training loss: 3.2717 0.0056 sec/batch
# Global Step: 24200 Epoch 10/20 Iteration: 24200 Avg. Training loss: 3.2655 0.0063 sec/batch
# Global Step: 24300 Epoch 10/20 Iteration: 24300 Avg. Training loss: 3.2863 0.0055 sec/batch
# Global Step: 24400 Epoch 10/20 Iteration: 24400 Avg. Training loss: 3.2717 0.0062 sec/batch
# Epoch 11/20 Threshold: 0.09654222674644326 Length of Training words: 2481922
# Global Step: 24500 Epoch 11/20 Iteration: 24500 Avg. Training loss: 3.2786 0.0058 sec/batch
# Global Step: 24600 Epoch 11/20 Iteration: 24600 Avg. Training loss: 3.2842 0.0078 sec/batch
# Global Step: 24700 Epoch 11/20 Iteration: 24700 Avg. Training loss: 3.2830 0.0063 sec/batch
# Global Step: 24800 Epoch 11/20 Iteration: 24800 Avg. Training loss: 3.2665 0.0056 sec/batch
# Global Step: 24900 Epoch 11/20 Iteration: 24900 Avg. Training loss: 3.2624 0.0056 sec/batch
# Global Step: 25000 Epoch 11/20 Iteration: 25000 Avg. Training loss: 3.2617 0.0063 sec/batch
# Global Step: 25100 Epoch 11/20 Iteration: 25100 Avg. Training loss: 3.2738 0.0060 sec/batch
# Global Step: 25200 Epoch 11/20 Iteration: 25200 Avg. Training loss: 3.2682 0.0060 sec/batch
# Global Step: 25300 Epoch 11/20 Iteration: 25300 Avg. Training loss: 3.2570 0.0056 sec/batch
# Global Step: 25400 Epoch 11/20 Iteration: 25400 Avg. Training loss: 3.2797 0.0057 sec/batch
# Global Step: 25500 Epoch 11/20 Iteration: 25500 Avg. Training loss: 3.2549 0.0072 sec/batch
# Global Step: 25600 Epoch 11/20 Iteration: 25600 Avg. Training loss: 3.2512 0.0062 sec/batch
# Global Step: 25700 Epoch 11/20 Iteration: 25700 Avg. Training loss: 3.2709 0.0068 sec/batch
# Global Step: 25800 Epoch 11/20 Iteration: 25800 Avg. Training loss: 3.2577 0.0057 sec/batch
# Global Step: 25900 Epoch 11/20 Iteration: 25900 Avg. Training loss: 3.2638 0.0068 sec/batch
# Global Step: 26000 Epoch 11/20 Iteration: 26000 Avg. Training loss: 3.2642 0.0055 sec/batch
# Global Step: 26100 Epoch 11/20 Iteration: 26100 Avg. Training loss: 3.2536 0.0057 sec/batch
# Global Step: 26200 Epoch 11/20 Iteration: 26200 Avg. Training loss: 3.2599 0.0057 sec/batch
# Global Step: 26300 Epoch 11/20 Iteration: 26300 Avg. Training loss: 3.2798 0.0058 sec/batch
# Global Step: 26400 Epoch 11/20 Iteration: 26400 Avg. Training loss: 3.2615 0.0057 sec/batch
# Global Step: 26500 Epoch 11/20 Iteration: 26500 Avg. Training loss: 3.2667 0.0063 sec/batch
# Global Step: 26600 Epoch 11/20 Iteration: 26600 Avg. Training loss: 3.2492 0.0063 sec/batch
# Global Step: 26700 Epoch 11/20 Iteration: 26700 Avg. Training loss: 3.2489 0.0070 sec/batch
# Global Step: 26800 Epoch 11/20 Iteration: 26800 Avg. Training loss: 3.2510 0.0063 sec/batch
# Global Step: 26900 Epoch 11/20 Iteration: 26900 Avg. Training loss: 3.2566 0.0074 sec/batch
# Epoch 12/20 Threshold: 0.09399495757284686 Length of Training words: 2470495
# Global Step: 27000 Epoch 12/20 Iteration: 27000 Avg. Training loss: 3.2707 0.0063 sec/batch
# Global Step: 27100 Epoch 12/20 Iteration: 27100 Avg. Training loss: 3.2877 0.0080 sec/batch
# Global Step: 27200 Epoch 12/20 Iteration: 27200 Avg. Training loss: 3.2677 0.0078 sec/batch
# Global Step: 27300 Epoch 12/20 Iteration: 27300 Avg. Training loss: 3.2613 0.0059 sec/batch
# Global Step: 27400 Epoch 12/20 Iteration: 27400 Avg. Training loss: 3.2541 0.0057 sec/batch
# Global Step: 27500 Epoch 12/20 Iteration: 27500 Avg. Training loss: 3.2579 0.0054 sec/batch
# Global Step: 27600 Epoch 12/20 Iteration: 27600 Avg. Training loss: 3.2630 0.0065 sec/batch
# Global Step: 27700 Epoch 12/20 Iteration: 27700 Avg. Training loss: 3.2654 0.0077 sec/batch
# Global Step: 27800 Epoch 12/20 Iteration: 27800 Avg. Training loss: 3.2604 0.0079 sec/batch
# Global Step: 27900 Epoch 12/20 Iteration: 27900 Avg. Training loss: 3.2605 0.0061 sec/batch
# Global Step: 28000 Epoch 12/20 Iteration: 28000 Avg. Training loss: 3.2505 0.0056 sec/batch
# Global Step: 28100 Epoch 12/20 Iteration: 28100 Avg. Training loss: 3.2565 0.0057 sec/batch
# Global Step: 28200 Epoch 12/20 Iteration: 28200 Avg. Training loss: 3.2645 0.0056 sec/batch
# Global Step: 28300 Epoch 12/20 Iteration: 28300 Avg. Training loss: 3.2529 0.0059 sec/batch
# Global Step: 28400 Epoch 12/20 Iteration: 28400 Avg. Training loss: 3.2660 0.0057 sec/batch
# Global Step: 28500 Epoch 12/20 Iteration: 28500 Avg. Training loss: 3.2562 0.0059 sec/batch
# Global Step: 28600 Epoch 12/20 Iteration: 28600 Avg. Training loss: 3.2447 0.0059 sec/batch
# Global Step: 28700 Epoch 12/20 Iteration: 28700 Avg. Training loss: 3.2736 0.0069 sec/batch
# Global Step: 28800 Epoch 12/20 Iteration: 28800 Avg. Training loss: 3.2617 0.0073 sec/batch
# Global Step: 28900 Epoch 12/20 Iteration: 28900 Avg. Training loss: 3.2681 0.0060 sec/batch
# Global Step: 29000 Epoch 12/20 Iteration: 29000 Avg. Training loss: 3.2635 0.0078 sec/batch
# Global Step: 29100 Epoch 12/20 Iteration: 29100 Avg. Training loss: 3.2470 0.0056 sec/batch
# Global Step: 29200 Epoch 12/20 Iteration: 29200 Avg. Training loss: 3.2468 0.0057 sec/batch
# Global Step: 29300 Epoch 12/20 Iteration: 29300 Avg. Training loss: 3.2478 0.0059 sec/batch
# Epoch 13/20 Threshold: 0.09575869430148072 Length of Training words: 2478714
# Global Step: 29400 Epoch 13/20 Iteration: 29400 Avg. Training loss: 3.2583 0.0018 sec/batch
# Global Step: 29500 Epoch 13/20 Iteration: 29500 Avg. Training loss: 3.2673 0.0062 sec/batch
# Global Step: 29600 Epoch 13/20 Iteration: 29600 Avg. Training loss: 3.2827 0.0057 sec/batch
# Global Step: 29700 Epoch 13/20 Iteration: 29700 Avg. Training loss: 3.2637 0.0057 sec/batch
# Global Step: 29800 Epoch 13/20 Iteration: 29800 Avg. Training loss: 3.2549 0.0074 sec/batch
# Global Step: 29900 Epoch 13/20 Iteration: 29900 Avg. Training loss: 3.2532 0.0075 sec/batch
# Global Step: 30000 Epoch 13/20 Iteration: 30000 Avg. Training loss: 3.2547 0.0064 sec/batch
# Global Step: 30100 Epoch 13/20 Iteration: 30100 Avg. Training loss: 3.2569 0.0060 sec/batch
# Global Step: 30200 Epoch 13/20 Iteration: 30200 Avg. Training loss: 3.2687 0.0058 sec/batch
# Global Step: 30300 Epoch 13/20 Iteration: 30300 Avg. Training loss: 3.2582 0.0064 sec/batch
# Global Step: 30400 Epoch 13/20 Iteration: 30400 Avg. Training loss: 3.2542 0.0080 sec/batch
# Global Step: 30500 Epoch 13/20 Iteration: 30500 Avg. Training loss: 3.2487 0.0068 sec/batch
# Global Step: 30600 Epoch 13/20 Iteration: 30600 Avg. Training loss: 3.2552 0.0089 sec/batch
# Global Step: 30700 Epoch 13/20 Iteration: 30700 Avg. Training loss: 3.2526 0.0075 sec/batch
# Global Step: 30800 Epoch 13/20 Iteration: 30800 Avg. Training loss: 3.2648 0.0063 sec/batch
# Global Step: 30900 Epoch 13/20 Iteration: 30900 Avg. Training loss: 3.2558 0.0062 sec/batch
# Global Step: 31000 Epoch 13/20 Iteration: 31000 Avg. Training loss: 3.2586 0.0059 sec/batch
# Global Step: 31100 Epoch 13/20 Iteration: 31100 Avg. Training loss: 3.2450 0.0060 sec/batch
# Global Step: 31200 Epoch 13/20 Iteration: 31200 Avg. Training loss: 3.2700 0.0081 sec/batch
# Global Step: 31300 Epoch 13/20 Iteration: 31300 Avg. Training loss: 3.2601 0.0059 sec/batch
# Global Step: 31400 Epoch 13/20 Iteration: 31400 Avg. Training loss: 3.2697 0.0059 sec/batch
# Global Step: 31500 Epoch 13/20 Iteration: 31500 Avg. Training loss: 3.2506 0.0075 sec/batch
# Global Step: 31600 Epoch 13/20 Iteration: 31600 Avg. Training loss: 3.2446 0.0062 sec/batch
# Global Step: 31700 Epoch 13/20 Iteration: 31700 Avg. Training loss: 3.2557 0.0088 sec/batch
# Global Step: 31800 Epoch 13/20 Iteration: 31800 Avg. Training loss: 3.2485 0.0063 sec/batch
# Epoch 14/20 Threshold: 0.09631853779435945 Length of Training words: 2481163
# Global Step: 31900 Epoch 14/20 Iteration: 31900 Avg. Training loss: 3.2574 0.0031 sec/batch
# Global Step: 32000 Epoch 14/20 Iteration: 32000 Avg. Training loss: 3.2702 0.0059 sec/batch
# Global Step: 32100 Epoch 14/20 Iteration: 32100 Avg. Training loss: 3.2718 0.0065 sec/batch
# Global Step: 32200 Epoch 14/20 Iteration: 32200 Avg. Training loss: 3.2637 0.0064 sec/batch
# Global Step: 32300 Epoch 14/20 Iteration: 32300 Avg. Training loss: 3.2544 0.0058 sec/batch
# Global Step: 32400 Epoch 14/20 Iteration: 32400 Avg. Training loss: 3.2501 0.0069 sec/batch
# Global Step: 32500 Epoch 14/20 Iteration: 32500 Avg. Training loss: 3.2547 0.0068 sec/batch
# Global Step: 32600 Epoch 14/20 Iteration: 32600 Avg. Training loss: 3.2630 0.0062 sec/batch
# Global Step: 32700 Epoch 14/20 Iteration: 32700 Avg. Training loss: 3.2535 0.0087 sec/batch
# Global Step: 32800 Epoch 14/20 Iteration: 32800 Avg. Training loss: 3.2685 0.0059 sec/batch
# Global Step: 32900 Epoch 14/20 Iteration: 32900 Avg. Training loss: 3.2481 0.0057 sec/batch
# Global Step: 33000 Epoch 14/20 Iteration: 33000 Avg. Training loss: 3.2486 0.0057 sec/batch
# Global Step: 33100 Epoch 14/20 Iteration: 33100 Avg. Training loss: 3.2600 0.0058 sec/batch
# Global Step: 33200 Epoch 14/20 Iteration: 33200 Avg. Training loss: 3.2536 0.0056 sec/batch
# Global Step: 33300 Epoch 14/20 Iteration: 33300 Avg. Training loss: 3.2570 0.0055 sec/batch
# Global Step: 33400 Epoch 14/20 Iteration: 33400 Avg. Training loss: 3.2547 0.0059 sec/batch
# Global Step: 33500 Epoch 14/20 Iteration: 33500 Avg. Training loss: 3.2607 0.0056 sec/batch
# Global Step: 33600 Epoch 14/20 Iteration: 33600 Avg. Training loss: 3.2485 0.0058 sec/batch
# Global Step: 33700 Epoch 14/20 Iteration: 33700 Avg. Training loss: 3.2703 0.0080 sec/batch
# Global Step: 33800 Epoch 14/20 Iteration: 33800 Avg. Training loss: 3.2588 0.0073 sec/batch
# Global Step: 33900 Epoch 14/20 Iteration: 33900 Avg. Training loss: 3.2657 0.0072 sec/batch
# Global Step: 34000 Epoch 14/20 Iteration: 34000 Avg. Training loss: 3.2455 0.0056 sec/batch
# Global Step: 34100 Epoch 14/20 Iteration: 34100 Avg. Training loss: 3.2408 0.0059 sec/batch
# Global Step: 34200 Epoch 14/20 Iteration: 34200 Avg. Training loss: 3.2611 0.0063 sec/batch
# Global Step: 34300 Epoch 14/20 Iteration: 34300 Avg. Training loss: 3.2472 0.0057 sec/batch
# Epoch 15/20 Threshold: 0.09969797834399798 Length of Training words: 2496760
# Global Step: 34400 Epoch 15/20 Iteration: 34400 Avg. Training loss: 3.2605 0.0043 sec/batch
# Global Step: 34500 Epoch 15/20 Iteration: 34500 Avg. Training loss: 3.2683 0.0056 sec/batch
# Global Step: 34600 Epoch 15/20 Iteration: 34600 Avg. Training loss: 3.2692 0.0063 sec/batch
# Global Step: 34700 Epoch 15/20 Iteration: 34700 Avg. Training loss: 3.2589 0.0076 sec/batch
# Global Step: 34800 Epoch 15/20 Iteration: 34800 Avg. Training loss: 3.2496 0.0068 sec/batch
# Global Step: 34900 Epoch 15/20 Iteration: 34900 Avg. Training loss: 3.2412 0.0070 sec/batch
# Global Step: 35000 Epoch 15/20 Iteration: 35000 Avg. Training loss: 3.2649 0.0064 sec/batch
# Global Step: 35100 Epoch 15/20 Iteration: 35100 Avg. Training loss: 3.2586 0.0061 sec/batch
# Global Step: 35200 Epoch 15/20 Iteration: 35200 Avg. Training loss: 3.2469 0.0061 sec/batch
# Global Step: 35300 Epoch 15/20 Iteration: 35300 Avg. Training loss: 3.2691 0.0059 sec/batch
# Global Step: 35400 Epoch 15/20 Iteration: 35400 Avg. Training loss: 3.2438 0.0056 sec/batch
# Global Step: 35500 Epoch 15/20 Iteration: 35500 Avg. Training loss: 3.2420 0.0065 sec/batch
# Global Step: 35600 Epoch 15/20 Iteration: 35600 Avg. Training loss: 3.2605 0.0056 sec/batch
# Global Step: 35700 Epoch 15/20 Iteration: 35700 Avg. Training loss: 3.2525 0.0056 sec/batch
# Global Step: 35800 Epoch 15/20 Iteration: 35800 Avg. Training loss: 3.2517 0.0058 sec/batch
# Global Step: 35900 Epoch 15/20 Iteration: 35900 Avg. Training loss: 3.2523 0.0056 sec/batch
# Global Step: 36000 Epoch 15/20 Iteration: 36000 Avg. Training loss: 3.2585 0.0095 sec/batch
# Global Step: 36100 Epoch 15/20 Iteration: 36100 Avg. Training loss: 3.2500 0.0094 sec/batch
# Global Step: 36200 Epoch 15/20 Iteration: 36200 Avg. Training loss: 3.2679 0.0078 sec/batch
# Global Step: 36300 Epoch 15/20 Iteration: 36300 Avg. Training loss: 3.2567 0.0077 sec/batch
# Global Step: 36400 Epoch 15/20 Iteration: 36400 Avg. Training loss: 3.2595 0.0059 sec/batch
# Global Step: 36500 Epoch 15/20 Iteration: 36500 Avg. Training loss: 3.2439 0.0084 sec/batch
# Global Step: 36600 Epoch 15/20 Iteration: 36600 Avg. Training loss: 3.2369 0.0067 sec/batch
# Global Step: 36700 Epoch 15/20 Iteration: 36700 Avg. Training loss: 3.2599 0.0066 sec/batch
# Global Step: 36800 Epoch 15/20 Iteration: 36800 Avg. Training loss: 3.2460 0.0062 sec/batch
# Epoch 16/20 Threshold: 0.0983504207346278 Length of Training words: 2490362
# Global Step: 36900 Epoch 16/20 Iteration: 36900 Avg. Training loss: 3.2618 0.0045 sec/batch
# Global Step: 37000 Epoch 16/20 Iteration: 37000 Avg. Training loss: 3.2688 0.0057 sec/batch
# Global Step: 37100 Epoch 16/20 Iteration: 37100 Avg. Training loss: 3.2730 0.0068 sec/batch
# Global Step: 37200 Epoch 16/20 Iteration: 37200 Avg. Training loss: 3.2546 0.0077 sec/batch
# Global Step: 37300 Epoch 16/20 Iteration: 37300 Avg. Training loss: 3.2518 0.0067 sec/batch
# Global Step: 37400 Epoch 16/20 Iteration: 37400 Avg. Training loss: 3.2440 0.0063 sec/batch
# Global Step: 37500 Epoch 16/20 Iteration: 37500 Avg. Training loss: 3.2675 0.0057 sec/batch
# Global Step: 37600 Epoch 16/20 Iteration: 37600 Avg. Training loss: 3.2603 0.0055 sec/batch
# Global Step: 37700 Epoch 16/20 Iteration: 37700 Avg. Training loss: 3.2445 0.0057 sec/batch
# Global Step: 37800 Epoch 16/20 Iteration: 37800 Avg. Training loss: 3.2717 0.0057 sec/batch
# Global Step: 37900 Epoch 16/20 Iteration: 37900 Avg. Training loss: 3.2437 0.0058 sec/batch
# Global Step: 38000 Epoch 16/20 Iteration: 38000 Avg. Training loss: 3.2415 0.0059 sec/batch
# Global Step: 38100 Epoch 16/20 Iteration: 38100 Avg. Training loss: 3.2611 0.0058 sec/batch
# Global Step: 38200 Epoch 16/20 Iteration: 38200 Avg. Training loss: 3.2535 0.0064 sec/batch
# Global Step: 38300 Epoch 16/20 Iteration: 38300 Avg. Training loss: 3.2537 0.0063 sec/batch
# Global Step: 38400 Epoch 16/20 Iteration: 38400 Avg. Training loss: 3.2569 0.0076 sec/batch
# Global Step: 38500 Epoch 16/20 Iteration: 38500 Avg. Training loss: 3.2533 0.0068 sec/batch
# Global Step: 38600 Epoch 16/20 Iteration: 38600 Avg. Training loss: 3.2517 0.0074 sec/batch
# Global Step: 38700 Epoch 16/20 Iteration: 38700 Avg. Training loss: 3.2723 0.0068 sec/batch
# Global Step: 38800 Epoch 16/20 Iteration: 38800 Avg. Training loss: 3.2553 0.0057 sec/batch
# Global Step: 38900 Epoch 16/20 Iteration: 38900 Avg. Training loss: 3.2618 0.0058 sec/batch
# Global Step: 39000 Epoch 16/20 Iteration: 39000 Avg. Training loss: 3.2436 0.0060 sec/batch
# Global Step: 39100 Epoch 16/20 Iteration: 39100 Avg. Training loss: 3.2392 0.0085 sec/batch
# Global Step: 39200 Epoch 16/20 Iteration: 39200 Avg. Training loss: 3.2531 0.0066 sec/batch
# Global Step: 39300 Epoch 16/20 Iteration: 39300 Avg. Training loss: 3.2489 0.0059 sec/batch
# Epoch 17/20 Threshold: 0.09121103250037682 Length of Training words: 2453577
# Global Step: 39400 Epoch 17/20 Iteration: 39400 Avg. Training loss: 3.2657 0.0068 sec/batch
# Global Step: 39500 Epoch 17/20 Iteration: 39500 Avg. Training loss: 3.2795 0.0073 sec/batch
# Global Step: 39600 Epoch 17/20 Iteration: 39600 Avg. Training loss: 3.2741 0.0059 sec/batch
# Global Step: 39700 Epoch 17/20 Iteration: 39700 Avg. Training loss: 3.2623 0.0066 sec/batch
# Global Step: 39800 Epoch 17/20 Iteration: 39800 Avg. Training loss: 3.2563 0.0059 sec/batch
# Global Step: 39900 Epoch 17/20 Iteration: 39900 Avg. Training loss: 3.2528 0.0079 sec/batch
# Global Step: 40000 Epoch 17/20 Iteration: 40000 Avg. Training loss: 3.2681 0.0063 sec/batch
# Global Step: 40100 Epoch 17/20 Iteration: 40100 Avg. Training loss: 3.2630 0.0080 sec/batch
# Global Step: 40200 Epoch 17/20 Iteration: 40200 Avg. Training loss: 3.2598 0.0056 sec/batch
# Global Step: 40300 Epoch 17/20 Iteration: 40300 Avg. Training loss: 3.2643 0.0058 sec/batch
# Global Step: 40400 Epoch 17/20 Iteration: 40400 Avg. Training loss: 3.2514 0.0061 sec/batch
# Global Step: 40500 Epoch 17/20 Iteration: 40500 Avg. Training loss: 3.2545 0.0057 sec/batch
# Global Step: 40600 Epoch 17/20 Iteration: 40600 Avg. Training loss: 3.2665 0.0056 sec/batch
# Global Step: 40700 Epoch 17/20 Iteration: 40700 Avg. Training loss: 3.2525 0.0058 sec/batch
# Global Step: 40800 Epoch 17/20 Iteration: 40800 Avg. Training loss: 3.2674 0.0056 sec/batch
# Global Step: 40900 Epoch 17/20 Iteration: 40900 Avg. Training loss: 3.2592 0.0061 sec/batch
# Global Step: 41000 Epoch 17/20 Iteration: 41000 Avg. Training loss: 3.2431 0.0060 sec/batch
# Global Step: 41100 Epoch 17/20 Iteration: 41100 Avg. Training loss: 3.2748 0.0071 sec/batch
# Global Step: 41200 Epoch 17/20 Iteration: 41200 Avg. Training loss: 3.2641 0.0103 sec/batch
# Global Step: 41300 Epoch 17/20 Iteration: 41300 Avg. Training loss: 3.2703 0.0064 sec/batch
# Global Step: 41400 Epoch 17/20 Iteration: 41400 Avg. Training loss: 3.2659 0.0058 sec/batch
# Global Step: 41500 Epoch 17/20 Iteration: 41500 Avg. Training loss: 3.2479 0.0057 sec/batch
# Global Step: 41600 Epoch 17/20 Iteration: 41600 Avg. Training loss: 3.2478 0.0056 sec/batch
# Global Step: 41700 Epoch 17/20 Iteration: 41700 Avg. Training loss: 3.2497 0.0067 sec/batch
# Epoch 18/20 Threshold: 0.09016400378328149 Length of Training words: 2447514
# Global Step: 41800 Epoch 18/20 Iteration: 41800 Avg. Training loss: 3.2620 0.0020 sec/batch
# Global Step: 41900 Epoch 18/20 Iteration: 41900 Avg. Training loss: 3.2702 0.0067 sec/batch
# Global Step: 42000 Epoch 18/20 Iteration: 42000 Avg. Training loss: 3.2873 0.0075 sec/batch
# Global Step: 42100 Epoch 18/20 Iteration: 42100 Avg. Training loss: 3.2701 0.0076 sec/batch
# Global Step: 42200 Epoch 18/20 Iteration: 42200 Avg. Training loss: 3.2563 0.0072 sec/batch
# Global Step: 42300 Epoch 18/20 Iteration: 42300 Avg. Training loss: 3.2560 0.0057 sec/batch
# Global Step: 42400 Epoch 18/20 Iteration: 42400 Avg. Training loss: 3.2602 0.0056 sec/batch
# Global Step: 42500 Epoch 18/20 Iteration: 42500 Avg. Training loss: 3.2638 0.0065 sec/batch
# Global Step: 42600 Epoch 18/20 Iteration: 42600 Avg. Training loss: 3.2643 0.0059 sec/batch
# Global Step: 42700 Epoch 18/20 Iteration: 42700 Avg. Training loss: 3.2718 0.0060 sec/batch
# Global Step: 42800 Epoch 18/20 Iteration: 42800 Avg. Training loss: 3.2503 0.0057 sec/batch
# Global Step: 42900 Epoch 18/20 Iteration: 42900 Avg. Training loss: 3.2543 0.0056 sec/batch
# Global Step: 43000 Epoch 18/20 Iteration: 43000 Avg. Training loss: 3.2649 0.0058 sec/batch
# Global Step: 43100 Epoch 18/20 Iteration: 43100 Avg. Training loss: 3.2598 0.0063 sec/batch
# Global Step: 43200 Epoch 18/20 Iteration: 43200 Avg. Training loss: 3.2609 0.0072 sec/batch
# Global Step: 43300 Epoch 18/20 Iteration: 43300 Avg. Training loss: 3.2593 0.0084 sec/batch
# Global Step: 43400 Epoch 18/20 Iteration: 43400 Avg. Training loss: 3.2640 0.0071 sec/batch
# Global Step: 43500 Epoch 18/20 Iteration: 43500 Avg. Training loss: 3.2558 0.0057 sec/batch
# Global Step: 43600 Epoch 18/20 Iteration: 43600 Avg. Training loss: 3.2756 0.0055 sec/batch
# Global Step: 43700 Epoch 18/20 Iteration: 43700 Avg. Training loss: 3.2658 0.0058 sec/batch
# Global Step: 43800 Epoch 18/20 Iteration: 43800 Avg. Training loss: 3.2660 0.0061 sec/batch
# Global Step: 43900 Epoch 18/20 Iteration: 43900 Avg. Training loss: 3.2528 0.0057 sec/batch
# Global Step: 44000 Epoch 18/20 Iteration: 44000 Avg. Training loss: 3.2435 0.0056 sec/batch
# Global Step: 44100 Epoch 18/20 Iteration: 44100 Avg. Training loss: 3.2625 0.0057 sec/batch
# Global Step: 44200 Epoch 18/20 Iteration: 44200 Avg. Training loss: 3.2533 0.0059 sec/batch
# Epoch 19/20 Threshold: 0.08344494336789729 Length of Training words: 2406596
# Global Step: 44300 Epoch 19/20 Iteration: 44300 Avg. Training loss: 3.2729 0.0066 sec/batch
# Global Step: 44400 Epoch 19/20 Iteration: 44400 Avg. Training loss: 3.2873 0.0057 sec/batch
# Global Step: 44500 Epoch 19/20 Iteration: 44500 Avg. Training loss: 3.2817 0.0056 sec/batch
# Global Step: 44600 Epoch 19/20 Iteration: 44600 Avg. Training loss: 3.2672 0.0057 sec/batch
# Global Step: 44700 Epoch 19/20 Iteration: 44700 Avg. Training loss: 3.2614 0.0057 sec/batch
# Global Step: 44800 Epoch 19/20 Iteration: 44800 Avg. Training loss: 3.2645 0.0059 sec/batch
# Global Step: 44900 Epoch 19/20 Iteration: 44900 Avg. Training loss: 3.2713 0.0057 sec/batch
# Global Step: 45000 Epoch 19/20 Iteration: 45000 Avg. Training loss: 3.2752 0.0058 sec/batch
# Global Step: 45100 Epoch 19/20 Iteration: 45100 Avg. Training loss: 3.2668 0.0056 sec/batch
# Global Step: 45200 Epoch 19/20 Iteration: 45200 Avg. Training loss: 3.2690 0.0060 sec/batch
# Global Step: 45300 Epoch 19/20 Iteration: 45300 Avg. Training loss: 3.2555 0.0081 sec/batch
# Global Step: 45400 Epoch 19/20 Iteration: 45400 Avg. Training loss: 3.2641 0.0080 sec/batch
# Global Step: 45500 Epoch 19/20 Iteration: 45500 Avg. Training loss: 3.2698 0.0056 sec/batch
# Global Step: 45600 Epoch 19/20 Iteration: 45600 Avg. Training loss: 3.2738 0.0057 sec/batch
# Global Step: 45700 Epoch 19/20 Iteration: 45700 Avg. Training loss: 3.2675 0.0059 sec/batch
# Global Step: 45800 Epoch 19/20 Iteration: 45800 Avg. Training loss: 3.2675 0.0058 sec/batch
# Global Step: 45900 Epoch 19/20 Iteration: 45900 Avg. Training loss: 3.2572 0.0057 sec/batch
# Global Step: 46000 Epoch 19/20 Iteration: 46000 Avg. Training loss: 3.2821 0.0063 sec/batch
# Global Step: 46100 Epoch 19/20 Iteration: 46100 Avg. Training loss: 3.2693 0.0063 sec/batch
# Global Step: 46200 Epoch 19/20 Iteration: 46200 Avg. Training loss: 3.2763 0.0055 sec/batch
# Global Step: 46300 Epoch 19/20 Iteration: 46300 Avg. Training loss: 3.2578 0.0058 sec/batch
# Global Step: 46400 Epoch 19/20 Iteration: 46400 Avg. Training loss: 3.2520 0.0085 sec/batch
# Global Step: 46500 Epoch 19/20 Iteration: 46500 Avg. Training loss: 3.2719 0.0059 sec/batch
# Global Step: 46600 Epoch 19/20 Iteration: 46600 Avg. Training loss: 3.2582 0.0084 sec/batch
# Epoch 20/20 Threshold: 0.08128621453966119 Length of Training words: 2393624
# Global Step: 46700 Epoch 20/20 Iteration: 46700 Avg. Training loss: 3.2772 0.0062 sec/batch
# Global Step: 46800 Epoch 20/20 Iteration: 46800 Avg. Training loss: 3.2860 0.0077 sec/batch
# Global Step: 46900 Epoch 20/20 Iteration: 46900 Avg. Training loss: 3.2840 0.0067 sec/batch
# Global Step: 47000 Epoch 20/20 Iteration: 47000 Avg. Training loss: 3.2721 0.0056 sec/batch
# Global Step: 47100 Epoch 20/20 Iteration: 47100 Avg. Training loss: 3.2644 0.0058 sec/batch
# Global Step: 47200 Epoch 20/20 Iteration: 47200 Avg. Training loss: 3.2671 0.0058 sec/batch
# Global Step: 47300 Epoch 20/20 Iteration: 47300 Avg. Training loss: 3.2715 0.0060 sec/batch
# Global Step: 47400 Epoch 20/20 Iteration: 47400 Avg. Training loss: 3.2737 0.0064 sec/batch
# Global Step: 47500 Epoch 20/20 Iteration: 47500 Avg. Training loss: 3.2689 0.0075 sec/batch
# Global Step: 47600 Epoch 20/20 Iteration: 47600 Avg. Training loss: 3.2702 0.0058 sec/batch
# Global Step: 47700 Epoch 20/20 Iteration: 47700 Avg. Training loss: 3.2578 0.0057 sec/batch
# Global Step: 47800 Epoch 20/20 Iteration: 47800 Avg. Training loss: 3.2655 0.0066 sec/batch
# Global Step: 47900 Epoch 20/20 Iteration: 47900 Avg. Training loss: 3.2712 0.0071 sec/batch
# Global Step: 48000 Epoch 20/20 Iteration: 48000 Avg. Training loss: 3.2756 0.0057 sec/batch
# Global Step: 48100 Epoch 20/20 Iteration: 48100 Avg. Training loss: 3.2697 0.0082 sec/batch
# Global Step: 48200 Epoch 20/20 Iteration: 48200 Avg. Training loss: 3.2690 0.0063 sec/batch
# Global Step: 48300 Epoch 20/20 Iteration: 48300 Avg. Training loss: 3.2580 0.0058 sec/batch
# Global Step: 48400 Epoch 20/20 Iteration: 48400 Avg. Training loss: 3.2864 0.0062 sec/batch
# Global Step: 48500 Epoch 20/20 Iteration: 48500 Avg. Training loss: 3.2705 0.0062 sec/batch
# Global Step: 48600 Epoch 20/20 Iteration: 48600 Avg. Training loss: 3.2786 0.0058 sec/batch
# Global Step: 48700 Epoch 20/20 Iteration: 48700 Avg. Training loss: 3.2597 0.0064 sec/batch
# Global Step: 48800 Epoch 20/20 Iteration: 48800 Avg. Training loss: 3.2540 0.0059 sec/batch
# Global Step: 48900 Epoch 20/20 Iteration: 48900 Avg. Training loss: 3.2744 0.0057 sec/batch
# Global Step: 49000 Epoch 20/20 Iteration: 49000 Avg. Training loss: 3.2607 0.0056 sec/batch

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints/' + model_name))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/pos_weighted_2/pos.ckpt

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

viz_words = n_vocab
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

fig, ax = plt.subplots(figsize=(16, 16))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='blue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=1, xytext=(embed_tsne[idx, 0]+1.5, embed_tsne[idx, 1]+1.5), fontsize=12)
