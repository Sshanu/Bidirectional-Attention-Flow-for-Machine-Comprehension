# %%
import time
import numpy as np
import tensorflow as tf
import re
from collections import Counter
from time import sleep
import json
import random

# %%
with open('data/pos_train.json') as json_data:
    d = json.load(json_data)

text=[]
l=0

for i in d:
    for j in i:
        for k in j:
            text.append(k)

tt = []
for i in range(len(text)):
    if(text[i]!=''):
        tt.append(text[i])

text = tt

for i in range(len(text)):
    if(text[i]=='$'or text[i]=='PDT' or text[i]=='WP$' or text[i]=="SYM" or text[i]=='LS' or text[i]=='#' or text[i]=='UH'):
        text[i]='OTHER'
    

word_counts = Counter(text)

word_counts.most_common()
# Out:
# [('NN', 391092),
#  ('IN', 313428),
#  ('NNP', 286327),
#  ('DT', 246818),
#  ('JJ', 194522),
#  ('NNS', 150057),
#  (',', 138811),
#  ('.', 92716),
#  ('CC', 86433),
#  ('VBD', 83807),
#  ('CD', 77651),
#  ('RB', 71899),
#  ('VBN', 69596),
#  ('TO', 48800),
#  ('VBZ', 41862),
#  ('VB', 40118),
#  ('VBG', 35283),
#  (':', 34343),
#  ('VBP', 28324),
#  ('PRP', 24380),
#  ('FW', 22213),
#  ('PRP$', 18771),
#  ('POS', 14923),
#  ('WDT', 13756),
#  ("''", 13344),
#  ('``', 12561),
#  ('MD', 11441),
#  ('NNPS', 10637),
#  ('JJS', 6400),
#  ('JJR', 6373),
#  ('WRB', 5119),
#  ('WP', 4378),
#  ('RP', 3189),
#  ('RBR', 2910),
#  ('OTHER', 2645),
#  ('EX', 2623),
#  ('RBS', 2274)]

# %%
def create_lookup_tables(words):
    """
    Create lookup tables for vocabulary
    :param words: Input list of words
    :return: A tuple of dicts.  The first dict....
    """
    word_counts = Counter(words)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {ii: word for ii, word in enumerate(sorted_vocab)}
    vocab_to_int = {word: ii for ii, word in int_to_vocab.items()}

    return vocab_to_int, int_to_vocab

def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)


def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
words = text

print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))

# vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
vocab_to_int, int_to_vocab = create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

word_counts = Counter(int_words)
total_count = len(int_words)
weights = [1 - 4*count/total_count for word, count in word_counts.items()]
# Out:
# Total words: 2609824
# Unique words: 37

# %%
def get_train_word():
    threshold = random.uniform(0.08, 0.1)
    word_counts = Counter(int_words)
    total_count = len(int_words)
    freqs = {word: count/total_count for word, count in word_counts.items()}
    p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
    train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]
    return train_words, threshold

# %%
batch_size = 1000
window_size = 5
n_vocab = len(int_to_vocab)
n_embedding =  25
starter_learning_rate = 0.0001
decay_steps = 2000
decay_rate = 0.96
lambda_l2 = 0.01

# %%
with tf.device('/device:GPU:3'):

    train_graph = tf.Graph()
    with train_graph.as_default():
        inputs = tf.placeholder(tf.int32, [None], name='inputs')
        labels = tf.placeholder(tf.int32, [None], name='labels')

        embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
        embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output
        embed_drop = tf.nn.dropout(embed, 0.8)

        softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding)), name="softmax_w") # create softmax weight matrix here
        softmax_b = tf.Variable(tf.zeros(n_vocab), name="softmax_bias") # create softmax biases here

        logits = tf.matmul(embed_drop, tf.transpose(softmax_w)) + softmax_b
        
        class_weight = tf.constant(weights)
        weighted_logits = logits * class_weight


        
        labels_one_hot = tf.one_hot(labels, n_vocab)
        
        tv_all = tf.trainable_variables()

        l2_loss = lambda_l2 * tf.reduce_sum([ tf.nn.l2_loss(v) for v in tv_all ])

        loss = tf.nn.softmax_cross_entropy_with_logits(labels=labels_one_hot, logits=weighted_logits)
        
        cost = tf.reduce_mean(loss) + l2_loss
        
        global_step = tf.Variable(0, trainable=False, name="global_step")

        learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, decay_steps, decay_rate)


        optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost, global_step=global_step)
        
        norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
        normalized_embedding = embedding / norm

# %%
model_name = 'pos_weighted_25'

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints/pos_weighted_25

# %%
epochs = 15

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    batch_loss = 0
    sess.run(tf.global_variables_initializer())
    
#     saver.restore(sess, tf.train.latest_checkpoint('checkpoints/pos'))
#     embed_mat = sess.run(embedding)
    
    for e in range(1, epochs+1):
        train_words, threshold = get_train_word()
        print("Epoch {}/{}".format(e, epochs), "Threshold: {}".format(threshold), "Length of Training words: {}".format(len(train_words)))
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            feed = {inputs: x,
                    labels: np.array(y)}
            global_steps, train_loss, _ = sess.run([global_step, cost, optimizer], feed_dict=feed)
            
            batch_loss += train_loss
            
            if iteration % 100== 0: 
                end = time.time()
                print("Global Step: {}".format(global_steps), "Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(batch_loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                batch_loss = 0
                start = time.time()
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/" + model_name + "/pos.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/15 Threshold: 0.09112144177784974 Length of Training words: 2453676
# Global Step: 100 Epoch 1/15 Iteration: 100 Avg. Training loss: 11.4768 0.0065 sec/batch
# Global Step: 200 Epoch 1/15 Iteration: 200 Avg. Training loss: 11.2241 0.0054 sec/batch
# Global Step: 300 Epoch 1/15 Iteration: 300 Avg. Training loss: 10.9580 0.0082 sec/batch
# Global Step: 400 Epoch 1/15 Iteration: 400 Avg. Training loss: 10.7260 0.0067 sec/batch
# Global Step: 500 Epoch 1/15 Iteration: 500 Avg. Training loss: 10.4974 0.0078 sec/batch
# Global Step: 600 Epoch 1/15 Iteration: 600 Avg. Training loss: 10.2725 0.0060 sec/batch
# Global Step: 700 Epoch 1/15 Iteration: 700 Avg. Training loss: 10.0833 0.0057 sec/batch
# Global Step: 800 Epoch 1/15 Iteration: 800 Avg. Training loss: 9.8709 0.0060 sec/batch
# Global Step: 900 Epoch 1/15 Iteration: 900 Avg. Training loss: 9.6851 0.0057 sec/batch
# Global Step: 1000 Epoch 1/15 Iteration: 1000 Avg. Training loss: 9.5056 0.0065 sec/batch
# Global Step: 1100 Epoch 1/15 Iteration: 1100 Avg. Training loss: 9.3289 0.0057 sec/batch
# Global Step: 1200 Epoch 1/15 Iteration: 1200 Avg. Training loss: 9.1532 0.0064 sec/batch
# Global Step: 1300 Epoch 1/15 Iteration: 1300 Avg. Training loss: 9.0009 0.0062 sec/batch
# Global Step: 1400 Epoch 1/15 Iteration: 1400 Avg. Training loss: 8.8403 0.0062 sec/batch
# Global Step: 1500 Epoch 1/15 Iteration: 1500 Avg. Training loss: 8.6878 0.0086 sec/batch
# Global Step: 1600 Epoch 1/15 Iteration: 1600 Avg. Training loss: 8.5390 0.0058 sec/batch
# Global Step: 1700 Epoch 1/15 Iteration: 1700 Avg. Training loss: 8.3890 0.0064 sec/batch
# Global Step: 1800 Epoch 1/15 Iteration: 1800 Avg. Training loss: 8.2792 0.0059 sec/batch
# Global Step: 1900 Epoch 1/15 Iteration: 1900 Avg. Training loss: 8.1345 0.0056 sec/batch
# Global Step: 2000 Epoch 1/15 Iteration: 2000 Avg. Training loss: 8.0195 0.0058 sec/batch
# Global Step: 2100 Epoch 1/15 Iteration: 2100 Avg. Training loss: 7.8810 0.0057 sec/batch
# Global Step: 2200 Epoch 1/15 Iteration: 2200 Avg. Training loss: 7.7579 0.0056 sec/batch
# Global Step: 2300 Epoch 1/15 Iteration: 2300 Avg. Training loss: 7.6468 0.0061 sec/batch
# Global Step: 2400 Epoch 1/15 Iteration: 2400 Avg. Training loss: 7.5291 0.0085 sec/batch
# Epoch 2/15 Threshold: 0.08884238996875658 Length of Training words: 2439347
# Global Step: 2500 Epoch 2/15 Iteration: 2500 Avg. Training loss: 7.4417 0.0036 sec/batch
# Global Step: 2600 Epoch 2/15 Iteration: 2600 Avg. Training loss: 7.3471 0.0065 sec/batch
# Global Step: 2700 Epoch 2/15 Iteration: 2700 Avg. Training loss: 7.2472 0.0057 sec/batch
# Global Step: 2800 Epoch 2/15 Iteration: 2800 Avg. Training loss: 7.1404 0.0059 sec/batch
# Global Step: 14400 Epoch 6/15 Iteration: 14400 Avg. Training loss: 3.4512 0.0074 sec/batch
# Global Step: 14500 Epoch 6/15 Iteration: 14500 Avg. Training loss: 3.4410 0.0070 sec/batch
# Global Step: 14600 Epoch 6/15 Iteration: 14600 Avg. Training loss: 3.4573 0.0092 sec/batch
# Global Step: 14700 Epoch 6/15 Iteration: 14700 Avg. Training loss: 3.4372 0.0075 sec/batch
# Epoch 7/15 Threshold: 0.08973484482242401 Length of Training words: 2445329
# Global Step: 14800 Epoch 7/15 Iteration: 14800 Avg. Training loss: 3.4504 0.0046 sec/batch
# Global Step: 14900 Epoch 7/15 Iteration: 14900 Avg. Training loss: 3.4548 0.0058 sec/batch
# Global Step: 15000 Epoch 7/15 Iteration: 15000 Avg. Training loss: 3.4485 0.0069 sec/batch
# Global Step: 15100 Epoch 7/15 Iteration: 15100 Avg. Training loss: 3.4265 0.0074 sec/batch
# Global Step: 15200 Epoch 7/15 Iteration: 15200 Avg. Training loss: 3.4203 0.0065 sec/batch
# Global Step: 15300 Epoch 7/15 Iteration: 15300 Avg. Training loss: 3.4153 0.0060 sec/batch
# Global Step: 15400 Epoch 7/15 Iteration: 15400 Avg. Training loss: 3.4211 0.0059 sec/batch
# Global Step: 15500 Epoch 7/15 Iteration: 15500 Avg. Training loss: 3.4128 0.0056 sec/batch
# Global Step: 15600 Epoch 7/15 Iteration: 15600 Avg. Training loss: 3.4025 0.0061 sec/batch
# Global Step: 15700 Epoch 7/15 Iteration: 15700 Avg. Training loss: 3.4109 0.0057 sec/batch
# Global Step: 15800 Epoch 7/15 Iteration: 15800 Avg. Training loss: 3.3887 0.0061 sec/batch
# Global Step: 15900 Epoch 7/15 Iteration: 15900 Avg. Training loss: 3.3896 0.0056 sec/batch
# Global Step: 16000 Epoch 7/15 Iteration: 16000 Avg. Training loss: 3.3965 0.0076 sec/batch
# Global Step: 16100 Epoch 7/15 Iteration: 16100 Avg. Training loss: 3.3771 0.0069 sec/batch
# Global Step: 16200 Epoch 7/15 Iteration: 16200 Avg. Training loss: 3.3906 0.0075 sec/batch
# Global Step: 16300 Epoch 7/15 Iteration: 16300 Avg. Training loss: 3.3753 0.0055 sec/batch
# Global Step: 16400 Epoch 7/15 Iteration: 16400 Avg. Training loss: 3.3598 0.0055 sec/batch
# Global Step: 16500 Epoch 7/15 Iteration: 16500 Avg. Training loss: 3.3854 0.0057 sec/batch
# Global Step: 16600 Epoch 7/15 Iteration: 16600 Avg. Training loss: 3.3740 0.0059 sec/batch
# Global Step: 16700 Epoch 7/15 Iteration: 16700 Avg. Training loss: 3.3753 0.0061 sec/batch
# Global Step: 16800 Epoch 7/15 Iteration: 16800 Avg. Training loss: 3.3682 0.0060 sec/batch
# Global Step: 16900 Epoch 7/15 Iteration: 16900 Avg. Training loss: 3.3453 0.0056 sec/batch
# Global Step: 17000 Epoch 7/15 Iteration: 17000 Avg. Training loss: 3.3439 0.0056 sec/batch
# Global Step: 17100 Epoch 7/15 Iteration: 17100 Avg. Training loss: 3.3430 0.0055 sec/batch
# Global Step: 31500 Epoch 13/15 Iteration: 31500 Avg. Training loss: 3.2411 0.0055 sec/batch
# Global Step: 31600 Epoch 13/15 Iteration: 31600 Avg. Training loss: 3.2647 0.0056 sec/batch
# Global Step: 31700 Epoch 13/15 Iteration: 31700 Avg. Training loss: 3.2516 0.0077 sec/batch
# Epoch 14/15 Threshold: 0.08497472026065685 Length of Training words: 2416232
# Global Step: 31800 Epoch 14/15 Iteration: 31800 Avg. Training loss: 3.2719 0.0048 sec/batch
# Global Step: 31900 Epoch 14/15 Iteration: 31900 Avg. Training loss: 3.2838 0.0075 sec/batch
# Global Step: 32000 Epoch 14/15 Iteration: 32000 Avg. Training loss: 3.2809 0.0058 sec/batch
# Global Step: 32100 Epoch 14/15 Iteration: 32100 Avg. Training loss: 3.2680 0.0055 sec/batch
# Global Step: 32200 Epoch 14/15 Iteration: 32200 Avg. Training loss: 3.2623 0.0057 sec/batch
# Global Step: 32300 Epoch 14/15 Iteration: 32300 Avg. Training loss: 3.2602 0.0075 sec/batch
# Global Step: 32400 Epoch 14/15 Iteration: 32400 Avg. Training loss: 3.2727 0.0056 sec/batch
# Global Step: 32500 Epoch 14/15 Iteration: 32500 Avg. Training loss: 3.2725 0.0056 sec/batch
# Global Step: 32600 Epoch 14/15 Iteration: 32600 Avg. Training loss: 3.2663 0.0055 sec/batch
# Global Step: 32700 Epoch 14/15 Iteration: 32700 Avg. Training loss: 3.2674 0.0064 sec/batch
# Global Step: 32800 Epoch 14/15 Iteration: 32800 Avg. Training loss: 3.2564 0.0071 sec/batch
# Global Step: 32900 Epoch 14/15 Iteration: 32900 Avg. Training loss: 3.2644 0.0060 sec/batch
# Global Step: 33000 Epoch 14/15 Iteration: 33000 Avg. Training loss: 3.2698 0.0056 sec/batch
# Global Step: 33100 Epoch 14/15 Iteration: 33100 Avg. Training loss: 3.2713 0.0078 sec/batch
# Global Step: 33200 Epoch 14/15 Iteration: 33200 Avg. Training loss: 3.2665 0.0056 sec/batch
# Global Step: 33300 Epoch 14/15 Iteration: 33300 Avg. Training loss: 3.2622 0.0058 sec/batch
# Global Step: 33400 Epoch 14/15 Iteration: 33400 Avg. Training loss: 3.2550 0.0055 sec/batch
# Global Step: 33500 Epoch 14/15 Iteration: 33500 Avg. Training loss: 3.2814 0.0057 sec/batch
# Global Step: 33600 Epoch 14/15 Iteration: 33600 Avg. Training loss: 3.2707 0.0056 sec/batch
# Global Step: 33700 Epoch 14/15 Iteration: 33700 Avg. Training loss: 3.2789 0.0063 sec/batch
# Global Step: 33800 Epoch 14/15 Iteration: 33800 Avg. Training loss: 3.2602 0.0058 sec/batch
# Global Step: 33900 Epoch 14/15 Iteration: 33900 Avg. Training loss: 3.2516 0.0061 sec/batch
# Global Step: 34000 Epoch 14/15 Iteration: 34000 Avg. Training loss: 3.2695 0.0057 sec/batch
# Global Step: 34100 Epoch 14/15 Iteration: 34100 Avg. Training loss: 3.2566 0.0071 sec/batch
# Epoch 15/15 Threshold: 0.09053584639604818 Length of Training words: 2449282
# Global Step: 34200 Epoch 15/15 Iteration: 34200 Avg. Training loss: 3.2670 0.0052 sec/batch
# Global Step: 34300 Epoch 15/15 Iteration: 34300 Avg. Training loss: 3.2757 0.0063 sec/batch
# Global Step: 34400 Epoch 15/15 Iteration: 34400 Avg. Training loss: 3.2755 0.0056 sec/batch
# Global Step: 34500 Epoch 15/15 Iteration: 34500 Avg. Training loss: 3.2674 0.0058 sec/batch
# Global Step: 34600 Epoch 15/15 Iteration: 34600 Avg. Training loss: 3.2570 0.0055 sec/batch
# Global Step: 34700 Epoch 15/15 Iteration: 34700 Avg. Training loss: 3.2499 0.0055 sec/batch
# Global Step: 34800 Epoch 15/15 Iteration: 34800 Avg. Training loss: 3.2744 0.0057 sec/batch
# Global Step: 34900 Epoch 15/15 Iteration: 34900 Avg. Training loss: 3.2660 0.0056 sec/batch
# Global Step: 35000 Epoch 15/15 Iteration: 35000 Avg. Training loss: 3.2523 0.0057 sec/batch
# Global Step: 35100 Epoch 15/15 Iteration: 35100 Avg. Training loss: 3.2784 0.0061 sec/batch
# Global Step: 35200 Epoch 15/15 Iteration: 35200 Avg. Training loss: 3.2505 0.0069 sec/batch
# Global Step: 35300 Epoch 15/15 Iteration: 35300 Avg. Training loss: 3.2487 0.0062 sec/batch
# Global Step: 35400 Epoch 15/15 Iteration: 35400 Avg. Training loss: 3.2691 0.0060 sec/batch
# Global Step: 35500 Epoch 15/15 Iteration: 35500 Avg. Training loss: 3.2557 0.0098 sec/batch
# Global Step: 35600 Epoch 15/15 Iteration: 35600 Avg. Training loss: 3.2655 0.0058 sec/batch
# Global Step: 35700 Epoch 15/15 Iteration: 35700 Avg. Training loss: 3.2625 0.0056 sec/batch
# Global Step: 35800 Epoch 15/15 Iteration: 35800 Avg. Training loss: 3.2489 0.0068 sec/batch
# Global Step: 35900 Epoch 15/15 Iteration: 35900 Avg. Training loss: 3.2659 0.0059 sec/batch
# Global Step: 36000 Epoch 15/15 Iteration: 36000 Avg. Training loss: 3.2783 0.0056 sec/batch
# Global Step: 36100 Epoch 15/15 Iteration: 36100 Avg. Training loss: 3.2633 0.0059 sec/batch
# Global Step: 36200 Epoch 15/15 Iteration: 36200 Avg. Training loss: 3.2653 0.0058 sec/batch
# Global Step: 36300 Epoch 15/15 Iteration: 36300 Avg. Training loss: 3.2522 0.0056 sec/batch
# Global Step: 36400 Epoch 15/15 Iteration: 36400 Avg. Training loss: 3.2473 0.0064 sec/batch
# Global Step: 36500 Epoch 15/15 Iteration: 36500 Avg. Training loss: 3.2563 0.0059 sec/batch

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints/' + model_name))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/pos_weighted_25/pos.ckpt

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

viz_words = n_vocab
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

fig, ax = plt.subplots(figsize=(16, 16))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='blue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=1, xytext=(embed_tsne[idx, 0]+1.5, embed_tsne[idx, 1]+1.5), fontsize=12)
