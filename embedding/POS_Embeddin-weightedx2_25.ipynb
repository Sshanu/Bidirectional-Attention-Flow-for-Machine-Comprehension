# %%
import time
import numpy as np
import tensorflow as tf
import re
from collections import Counter
from time import sleep
import json
import random

with open('data/pos_train.json') as json_data:
    d = json.load(json_data)

text=[]
l=0

for i in d:
    for j in i:
        for k in j:
            text.append(k)

tt = []
for i in range(len(text)):
    if(text[i]!=''):
        tt.append(text[i])

text = tt

for i in range(len(text)):
    if(text[i]=='$'or text[i]=='PDT' or text[i]=='WP$' or text[i]=="SYM" or text[i]=='LS' or text[i]=='#' or text[i]=='UH'):
        text[i]='OTHER'
    

word_counts = Counter(text)

word_counts.most_common()
# Out:
# [('NN', 391092),
#  ('IN', 313428),
#  ('NNP', 286327),
#  ('DT', 246818),
#  ('JJ', 194522),
#  ('NNS', 150057),
#  (',', 138811),
#  ('.', 92716),
#  ('CC', 86433),
#  ('VBD', 83807),
#  ('CD', 77651),
#  ('RB', 71899),
#  ('VBN', 69596),
#  ('TO', 48800),
#  ('VBZ', 41862),
#  ('VB', 40118),
#  ('VBG', 35283),
#  (':', 34343),
#  ('VBP', 28324),
#  ('PRP', 24380),
#  ('FW', 22213),
#  ('PRP$', 18771),
#  ('POS', 14923),
#  ('WDT', 13756),
#  ("''", 13344),
#  ('``', 12561),
#  ('MD', 11441),
#  ('NNPS', 10637),
#  ('JJS', 6400),
#  ('JJR', 6373),
#  ('WRB', 5119),
#  ('WP', 4378),
#  ('RP', 3189),
#  ('RBR', 2910),
#  ('OTHER', 2645),
#  ('EX', 2623),
#  ('RBS', 2274)]

# %%
def create_lookup_tables(words):
    """
    Create lookup tables for vocabulary
    :param words: Input list of words
    :return: A tuple of dicts.  The first dict....
    """
    word_counts = Counter(words)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {ii: word for ii, word in enumerate(sorted_vocab)}
    vocab_to_int = {word: ii for ii, word in int_to_vocab.items()}

    return vocab_to_int, int_to_vocab

def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)


def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
words = text

print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))

# vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
vocab_to_int, int_to_vocab = create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

word_counts = Counter(int_words)
total_count = len(int_words)
weights = [1 - 4*count/total_count for word, count in word_counts.items()]
weights = 2*np.multiply(weights, weights)
# Out:
# Total words: 2609824
# Unique words: 37

# %%
weights = weights.astype(np.float32)

# %%
def get_train_word():
    threshold = random.uniform(0.08, 0.1)
    word_counts = Counter(int_words)
    total_count = len(int_words)
    freqs = {word: count/total_count for word, count in word_counts.items()}
    p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
    train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]
    return train_words, threshold

# %%
batch_size = 1000
window_size = 5
n_vocab = len(int_to_vocab)
n_embedding =  25
starter_learning_rate = 0.0001
decay_steps = 2000
decay_rate = 0.96
lambda_l2 = 0.01

# %%
with tf.device('/device:GPU:3'):

    train_graph = tf.Graph()
    with train_graph.as_default():
        inputs = tf.placeholder(tf.int32, [None], name='inputs')
        labels = tf.placeholder(tf.int32, [None], name='labels')

        embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
        embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output
        embed_drop = tf.nn.dropout(embed, 0.8)

        softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding)), name="softmax_w") # create softmax weight matrix here
        softmax_b = tf.Variable(tf.zeros(n_vocab), name="softmax_bias") # create softmax biases here

        logits = tf.matmul(embed_drop, tf.transpose(softmax_w)) + softmax_b
        
        class_weight = tf.constant(weights)
        weighted_logits = logits * class_weight


        
        labels_one_hot = tf.one_hot(labels, n_vocab)
        
        tv_all = tf.trainable_variables()

        l2_loss = lambda_l2 * tf.reduce_sum([ tf.nn.l2_loss(v) for v in tv_all ])

        loss = tf.nn.softmax_cross_entropy_with_logits(labels=labels_one_hot, logits=weighted_logits)
        
        cost = tf.reduce_mean(loss) + l2_loss
        
        global_step = tf.Variable(0, trainable=False, name="global_step")

        learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, decay_steps, decay_rate)


        optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost, global_step=global_step)
        
        norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
        normalized_embedding = embedding / norm

# %%
model_name = 'pos_weighted_25_2'

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints/pos_weighted_25_2

# %%
epochs = 15

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    batch_loss = 0
    sess.run(tf.global_variables_initializer())
    
#     saver.restore(sess, tf.train.latest_checkpoint('checkpoints/pos'))
#     embed_mat = sess.run(embedding)
    
    for e in range(1, epochs+1):
        train_words, threshold = get_train_word()
        print("Epoch {}/{}".format(e, epochs), "Threshold: {}".format(threshold), "Length of Training words: {}".format(len(train_words)))
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            feed = {inputs: x,
                    labels: np.array(y)}
            global_steps, train_loss, _ = sess.run([global_step, cost, optimizer], feed_dict=feed)
            
            batch_loss += train_loss
            
            if iteration % 100== 0: 
                end = time.time()
                print("Global Step: {}".format(global_steps), "Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(batch_loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                batch_loss = 0
                start = time.time()
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/" + model_name + "/pos.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/15 Threshold: 0.08353182561491597 Length of Training words: 2407139
# Global Step: 100 Epoch 1/15 Iteration: 100 Avg. Training loss: 16.9829 0.0264 sec/batch
# Global Step: 200 Epoch 1/15 Iteration: 200 Avg. Training loss: 16.5057 0.0080 sec/batch
# Global Step: 300 Epoch 1/15 Iteration: 300 Avg. Training loss: 16.0090 0.0054 sec/batch
# Global Step: 400 Epoch 1/15 Iteration: 400 Avg. Training loss: 15.5565 0.0053 sec/batch
# Global Step: 500 Epoch 1/15 Iteration: 500 Avg. Training loss: 15.0896 0.0081 sec/batch
# Global Step: 600 Epoch 1/15 Iteration: 600 Avg. Training loss: 14.6864 0.0084 sec/batch
# Global Step: 700 Epoch 1/15 Iteration: 700 Avg. Training loss: 14.2726 0.0091 sec/batch
# Global Step: 800 Epoch 1/15 Iteration: 800 Avg. Training loss: 13.8405 0.0052 sec/batch
# Global Step: 900 Epoch 1/15 Iteration: 900 Avg. Training loss: 13.4791 0.0062 sec/batch
# Global Step: 1000 Epoch 1/15 Iteration: 1000 Avg. Training loss: 13.0961 0.0063 sec/batch
# Global Step: 1100 Epoch 1/15 Iteration: 1100 Avg. Training loss: 12.7619 0.0063 sec/batch
# Global Step: 1200 Epoch 1/15 Iteration: 1200 Avg. Training loss: 12.4014 0.0095 sec/batch
# Global Step: 1300 Epoch 1/15 Iteration: 1300 Avg. Training loss: 12.0646 0.0067 sec/batch
# Global Step: 1400 Epoch 1/15 Iteration: 1400 Avg. Training loss: 11.7960 0.0065 sec/batch
# Global Step: 1500 Epoch 1/15 Iteration: 1500 Avg. Training loss: 11.4764 0.0079 sec/batch
# Global Step: 1600 Epoch 1/15 Iteration: 1600 Avg. Training loss: 11.2017 0.0055 sec/batch
# Global Step: 1700 Epoch 1/15 Iteration: 1700 Avg. Training loss: 10.9420 0.0060 sec/batch
# Global Step: 1800 Epoch 1/15 Iteration: 1800 Avg. Training loss: 10.6587 0.0057 sec/batch
# Global Step: 1900 Epoch 1/15 Iteration: 1900 Avg. Training loss: 10.4409 0.0061 sec/batch
# Global Step: 2000 Epoch 1/15 Iteration: 2000 Avg. Training loss: 10.2003 0.0080 sec/batch
# Global Step: 2100 Epoch 1/15 Iteration: 2100 Avg. Training loss: 9.9543 0.0076 sec/batch
# Global Step: 2200 Epoch 1/15 Iteration: 2200 Avg. Training loss: 9.7082 0.0054 sec/batch
# Global Step: 2300 Epoch 1/15 Iteration: 2300 Avg. Training loss: 9.5022 0.0054 sec/batch
# Global Step: 2400 Epoch 1/15 Iteration: 2400 Avg. Training loss: 9.3106 0.0074 sec/batch
# Epoch 2/15 Threshold: 0.08289668930864234 Length of Training words: 2404391
# Global Step: 2500 Epoch 2/15 Iteration: 2500 Avg. Training loss: 9.1448 0.0072 sec/batch
# Global Step: 2600 Epoch 2/15 Iteration: 2600 Avg. Training loss: 8.9577 0.0066 sec/batch
# Global Step: 2700 Epoch 2/15 Iteration: 2700 Avg. Training loss: 8.7674 0.0060 sec/batch
# Global Step: 2800 Epoch 2/15 Iteration: 2800 Avg. Training loss: 8.5966 0.0078 sec/batch
# Global Step: 2900 Epoch 2/15 Iteration: 2900 Avg. Training loss: 8.4249 0.0055 sec/batch
# Global Step: 3000 Epoch 2/15 Iteration: 3000 Avg. Training loss: 8.2679 0.0063 sec/batch
# Global Step: 3100 Epoch 2/15 Iteration: 3100 Avg. Training loss: 8.1211 0.0058 sec/batch
# Global Step: 3200 Epoch 2/15 Iteration: 3200 Avg. Training loss: 7.9735 0.0082 sec/batch
# Global Step: 3300 Epoch 2/15 Iteration: 3300 Avg. Training loss: 7.8321 0.0075 sec/batch
# Global Step: 3400 Epoch 2/15 Iteration: 3400 Avg. Training loss: 7.7078 0.0085 sec/batch
# Global Step: 3500 Epoch 2/15 Iteration: 3500 Avg. Training loss: 7.5604 0.0072 sec/batch
# Global Step: 3600 Epoch 2/15 Iteration: 3600 Avg. Training loss: 7.4374 0.0053 sec/batch
# Global Step: 3700 Epoch 2/15 Iteration: 3700 Avg. Training loss: 7.3045 0.0053 sec/batch
# Global Step: 3800 Epoch 2/15 Iteration: 3800 Avg. Training loss: 7.2104 0.0060 sec/batch
# Global Step: 3900 Epoch 2/15 Iteration: 3900 Avg. Training loss: 7.0838 0.0072 sec/batch
# Global Step: 4000 Epoch 2/15 Iteration: 4000 Avg. Training loss: 6.9813 0.0053 sec/batch
# Global Step: 4100 Epoch 2/15 Iteration: 4100 Avg. Training loss: 6.8650 0.0055 sec/batch
# Global Step: 4200 Epoch 2/15 Iteration: 4200 Avg. Training loss: 6.7729 0.0060 sec/batch
# Global Step: 4300 Epoch 2/15 Iteration: 4300 Avg. Training loss: 6.6771 0.0062 sec/batch
# Global Step: 4400 Epoch 2/15 Iteration: 4400 Avg. Training loss: 6.5889 0.0081 sec/batch
# Global Step: 4500 Epoch 2/15 Iteration: 4500 Avg. Training loss: 6.4729 0.0076 sec/batch
# Global Step: 4600 Epoch 2/15 Iteration: 4600 Avg. Training loss: 6.3659 0.0061 sec/batch
# Global Step: 4700 Epoch 2/15 Iteration: 4700 Avg. Training loss: 6.2918 0.0056 sec/batch
# Global Step: 4800 Epoch 2/15 Iteration: 4800 Avg. Training loss: 6.2098 0.0054 sec/batch
# Epoch 3/15 Threshold: 0.08372362865017968 Length of Training words: 2408297
# Global Step: 4900 Epoch 3/15 Iteration: 4900 Avg. Training loss: 6.1472 0.0055 sec/batch
# Global Step: 5000 Epoch 3/15 Iteration: 5000 Avg. Training loss: 6.0832 0.0057 sec/batch
# Global Step: 5100 Epoch 3/15 Iteration: 5100 Avg. Training loss: 5.9911 0.0075 sec/batch
# Global Step: 5200 Epoch 3/15 Iteration: 5200 Avg. Training loss: 5.9091 0.0071 sec/batch
# Global Step: 5300 Epoch 3/15 Iteration: 5300 Avg. Training loss: 5.8286 0.0065 sec/batch
# Global Step: 5400 Epoch 3/15 Iteration: 5400 Avg. Training loss: 5.7560 0.0070 sec/batch
# Global Step: 5500 Epoch 3/15 Iteration: 5500 Avg. Training loss: 5.7028 0.0055 sec/batch
# Global Step: 5600 Epoch 3/15 Iteration: 5600 Avg. Training loss: 5.6380 0.0072 sec/batch
# Global Step: 5700 Epoch 3/15 Iteration: 5700 Avg. Training loss: 5.5708 0.0086 sec/batch
# Global Step: 5800 Epoch 3/15 Iteration: 5800 Avg. Training loss: 5.5109 0.0052 sec/batch
# Global Step: 5900 Epoch 3/15 Iteration: 5900 Avg. Training loss: 5.4275 0.0069 sec/batch
# Global Step: 6000 Epoch 3/15 Iteration: 6000 Avg. Training loss: 5.3859 0.0059 sec/batch
# Global Step: 6100 Epoch 3/15 Iteration: 6100 Avg. Training loss: 5.3256 0.0074 sec/batch
# Global Step: 6200 Epoch 3/15 Iteration: 6200 Avg. Training loss: 5.2898 0.0073 sec/batch
# Global Step: 6300 Epoch 3/15 Iteration: 6300 Avg. Training loss: 5.2263 0.0057 sec/batch
# Global Step: 6400 Epoch 3/15 Iteration: 6400 Avg. Training loss: 5.1743 0.0062 sec/batch
# Global Step: 6500 Epoch 3/15 Iteration: 6500 Avg. Training loss: 5.1117 0.0065 sec/batch
# Global Step: 6600 Epoch 3/15 Iteration: 6600 Avg. Training loss: 5.0891 0.0061 sec/batch
# Global Step: 6700 Epoch 3/15 Iteration: 6700 Avg. Training loss: 5.0339 0.0072 sec/batch
# Global Step: 6800 Epoch 3/15 Iteration: 6800 Avg. Training loss: 4.9958 0.0082 sec/batch
# Global Step: 6900 Epoch 3/15 Iteration: 6900 Avg. Training loss: 4.9235 0.0073 sec/batch
# Global Step: 7000 Epoch 3/15 Iteration: 7000 Avg. Training loss: 4.8651 0.0075 sec/batch
# Global Step: 7100 Epoch 3/15 Iteration: 7100 Avg. Training loss: 4.8495 0.0068 sec/batch
# Global Step: 7200 Epoch 3/15 Iteration: 7200 Avg. Training loss: 4.7977 0.0089 sec/batch
# Epoch 4/15 Threshold: 0.09521256510966972 Length of Training words: 2476521
# Global Step: 7300 Epoch 4/15 Iteration: 7300 Avg. Training loss: 4.7669 0.0075 sec/batch
# Global Step: 7400 Epoch 4/15 Iteration: 7400 Avg. Training loss: 4.7353 0.0075 sec/batch
# Global Step: 7500 Epoch 4/15 Iteration: 7500 Avg. Training loss: 4.6915 0.0066 sec/batch
# Global Step: 7600 Epoch 4/15 Iteration: 7600 Avg. Training loss: 4.6376 0.0080 sec/batch
# Global Step: 7700 Epoch 4/15 Iteration: 7700 Avg. Training loss: 4.5984 0.0062 sec/batch
# Global Step: 7800 Epoch 4/15 Iteration: 7800 Avg. Training loss: 4.5604 0.0052 sec/batch
# Global Step: 7900 Epoch 4/15 Iteration: 7900 Avg. Training loss: 4.5385 0.0065 sec/batch
# Global Step: 8000 Epoch 4/15 Iteration: 8000 Avg. Training loss: 4.5043 0.0065 sec/batch
# Global Step: 8100 Epoch 4/15 Iteration: 8100 Avg. Training loss: 4.4566 0.0063 sec/batch
# Global Step: 8200 Epoch 4/15 Iteration: 8200 Avg. Training loss: 4.4455 0.0064 sec/batch
# Global Step: 8300 Epoch 4/15 Iteration: 8300 Avg. Training loss: 4.3881 0.0079 sec/batch
# Global Step: 8400 Epoch 4/15 Iteration: 8400 Avg. Training loss: 4.3556 0.0064 sec/batch
# Global Step: 8500 Epoch 4/15 Iteration: 8500 Avg. Training loss: 4.3457 0.0052 sec/batch
# Global Step: 8600 Epoch 4/15 Iteration: 8600 Avg. Training loss: 4.2960 0.0056 sec/batch
# Global Step: 8700 Epoch 4/15 Iteration: 8700 Avg. Training loss: 4.2892 0.0056 sec/batch
# Global Step: 8800 Epoch 4/15 Iteration: 8800 Avg. Training loss: 4.2542 0.0074 sec/batch
# Global Step: 8900 Epoch 4/15 Iteration: 8900 Avg. Training loss: 4.2109 0.0080 sec/batch
# Global Step: 9000 Epoch 4/15 Iteration: 9000 Avg. Training loss: 4.2038 0.0083 sec/batch
# Global Step: 9100 Epoch 4/15 Iteration: 9100 Avg. Training loss: 4.1928 0.0064 sec/batch
# Global Step: 9200 Epoch 4/15 Iteration: 9200 Avg. Training loss: 4.1497 0.0066 sec/batch
# Global Step: 9300 Epoch 4/15 Iteration: 9300 Avg. Training loss: 4.1318 0.0098 sec/batch
# Global Step: 9400 Epoch 4/15 Iteration: 9400 Avg. Training loss: 4.0916 0.0071 sec/batch
# Global Step: 9500 Epoch 4/15 Iteration: 9500 Avg. Training loss: 4.0565 0.0081 sec/batch
# Global Step: 9600 Epoch 4/15 Iteration: 9600 Avg. Training loss: 4.0403 0.0069 sec/batch
# Epoch 5/15 Threshold: 0.09516505690943285 Length of Training words: 2476434
# Global Step: 9700 Epoch 5/15 Iteration: 9700 Avg. Training loss: 4.0239 0.0003 sec/batch
# Global Step: 9800 Epoch 5/15 Iteration: 9800 Avg. Training loss: 4.0272 0.0066 sec/batch
# Global Step: 9900 Epoch 5/15 Iteration: 9900 Avg. Training loss: 4.0103 0.0057 sec/batch
# Global Step: 10000 Epoch 5/15 Iteration: 10000 Avg. Training loss: 3.9741 0.0059 sec/batch
# Global Step: 10100 Epoch 5/15 Iteration: 10100 Avg. Training loss: 3.9409 0.0075 sec/batch
# Global Step: 10200 Epoch 5/15 Iteration: 10200 Avg. Training loss: 3.9215 0.0083 sec/batch
# Global Step: 10300 Epoch 5/15 Iteration: 10300 Avg. Training loss: 3.9002 0.0074 sec/batch
# Global Step: 10400 Epoch 5/15 Iteration: 10400 Avg. Training loss: 3.8924 0.0067 sec/batch
# Global Step: 10500 Epoch 5/15 Iteration: 10500 Avg. Training loss: 3.8762 0.0083 sec/batch
# Global Step: 10600 Epoch 5/15 Iteration: 10600 Avg. Training loss: 3.8527 0.0055 sec/batch
# Global Step: 10700 Epoch 5/15 Iteration: 10700 Avg. Training loss: 3.8314 0.0056 sec/batch
# Global Step: 10800 Epoch 5/15 Iteration: 10800 Avg. Training loss: 3.8024 0.0059 sec/batch
# Global Step: 10900 Epoch 5/15 Iteration: 10900 Avg. Training loss: 3.7972 0.0062 sec/batch
# Global Step: 11000 Epoch 5/15 Iteration: 11000 Avg. Training loss: 3.7839 0.0063 sec/batch
# Global Step: 11100 Epoch 5/15 Iteration: 11100 Avg. Training loss: 3.7653 0.0081 sec/batch
# Global Step: 11200 Epoch 5/15 Iteration: 11200 Avg. Training loss: 3.7579 0.0052 sec/batch
# Global Step: 11300 Epoch 5/15 Iteration: 11300 Avg. Training loss: 3.7332 0.0054 sec/batch
# Global Step: 11400 Epoch 5/15 Iteration: 11400 Avg. Training loss: 3.7068 0.0071 sec/batch
# Global Step: 11500 Epoch 5/15 Iteration: 11500 Avg. Training loss: 3.7251 0.0057 sec/batch
# Global Step: 11600 Epoch 5/15 Iteration: 11600 Avg. Training loss: 3.6974 0.0088 sec/batch
# Global Step: 11700 Epoch 5/15 Iteration: 11700 Avg. Training loss: 3.6917 0.0069 sec/batch
# Global Step: 11800 Epoch 5/15 Iteration: 11800 Avg. Training loss: 3.6737 0.0068 sec/batch
# Global Step: 11900 Epoch 5/15 Iteration: 11900 Avg. Training loss: 3.6403 0.0061 sec/batch
# Global Step: 12000 Epoch 5/15 Iteration: 12000 Avg. Training loss: 3.6264 0.0072 sec/batch
# Global Step: 12100 Epoch 5/15 Iteration: 12100 Avg. Training loss: 3.6170 0.0072 sec/batch
# Epoch 6/15 Threshold: 0.08015283530698668 Length of Training words: 2386681
# Global Step: 12200 Epoch 6/15 Iteration: 12200 Avg. Training loss: 3.6219 0.0020 sec/batch
# Global Step: 12300 Epoch 6/15 Iteration: 12300 Avg. Training loss: 3.6275 0.0067 sec/batch
# Global Step: 12400 Epoch 6/15 Iteration: 12400 Avg. Training loss: 3.6356 0.0084 sec/batch
# Global Step: 12500 Epoch 6/15 Iteration: 12500 Avg. Training loss: 3.6080 0.0064 sec/batch
# Global Step: 12600 Epoch 6/15 Iteration: 12600 Avg. Training loss: 3.5820 0.0064 sec/batch
# Global Step: 12700 Epoch 6/15 Iteration: 12700 Avg. Training loss: 3.5686 0.0064 sec/batch
# Global Step: 12800 Epoch 6/15 Iteration: 12800 Avg. Training loss: 3.5641 0.0072 sec/batch
# Global Step: 12900 Epoch 6/15 Iteration: 12900 Avg. Training loss: 3.5576 0.0075 sec/batch
# Global Step: 13000 Epoch 6/15 Iteration: 13000 Avg. Training loss: 3.5432 0.0060 sec/batch
# Global Step: 13100 Epoch 6/15 Iteration: 13100 Avg. Training loss: 3.5518 0.0058 sec/batch
# Global Step: 13200 Epoch 6/15 Iteration: 13200 Avg. Training loss: 3.5139 0.0054 sec/batch
# Global Step: 13300 Epoch 6/15 Iteration: 13300 Avg. Training loss: 3.5022 0.0055 sec/batch
# Global Step: 13400 Epoch 6/15 Iteration: 13400 Avg. Training loss: 3.5180 0.0062 sec/batch
# Global Step: 13500 Epoch 6/15 Iteration: 13500 Avg. Training loss: 3.4915 0.0059 sec/batch
# Global Step: 13600 Epoch 6/15 Iteration: 13600 Avg. Training loss: 3.4966 0.0080 sec/batch
# Global Step: 13700 Epoch 6/15 Iteration: 13700 Avg. Training loss: 3.4807 0.0056 sec/batch
# Global Step: 13800 Epoch 6/15 Iteration: 13800 Avg. Training loss: 3.4606 0.0057 sec/batch
# Global Step: 13900 Epoch 6/15 Iteration: 13900 Avg. Training loss: 3.4802 0.0061 sec/batch
# Global Step: 14000 Epoch 6/15 Iteration: 14000 Avg. Training loss: 3.4660 0.0069 sec/batch
# Global Step: 14100 Epoch 6/15 Iteration: 14100 Avg. Training loss: 3.4630 0.0055 sec/batch
# Global Step: 14200 Epoch 6/15 Iteration: 14200 Avg. Training loss: 3.4508 0.0059 sec/batch
# Global Step: 14300 Epoch 6/15 Iteration: 14300 Avg. Training loss: 3.4253 0.0082 sec/batch
# Global Step: 14400 Epoch 6/15 Iteration: 14400 Avg. Training loss: 3.4201 0.0101 sec/batch
# Global Step: 14500 Epoch 6/15 Iteration: 14500 Avg. Training loss: 3.4130 0.0092 sec/batch
# Epoch 7/15 Threshold: 0.09066753926350254 Length of Training words: 2450940
# Global Step: 14600 Epoch 7/15 Iteration: 14600 Avg. Training loss: 3.4203 0.0029 sec/batch
# Global Step: 14700 Epoch 7/15 Iteration: 14700 Avg. Training loss: 3.4125 0.0067 sec/batch
# Global Step: 14800 Epoch 7/15 Iteration: 14800 Avg. Training loss: 3.4164 0.0074 sec/batch
# Global Step: 14900 Epoch 7/15 Iteration: 14900 Avg. Training loss: 3.3989 0.0058 sec/batch
# Global Step: 15000 Epoch 7/15 Iteration: 15000 Avg. Training loss: 3.3796 0.0062 sec/batch
# Global Step: 15100 Epoch 7/15 Iteration: 15100 Avg. Training loss: 3.3731 0.0052 sec/batch
# Global Step: 15200 Epoch 7/15 Iteration: 15200 Avg. Training loss: 3.3691 0.0090 sec/batch
# Global Step: 15300 Epoch 7/15 Iteration: 15300 Avg. Training loss: 3.3728 0.0067 sec/batch
# Global Step: 15400 Epoch 7/15 Iteration: 15400 Avg. Training loss: 3.3572 0.0070 sec/batch
# Global Step: 15500 Epoch 7/15 Iteration: 15500 Avg. Training loss: 3.3716 0.0067 sec/batch
# Global Step: 15600 Epoch 7/15 Iteration: 15600 Avg. Training loss: 3.3409 0.0076 sec/batch
# Global Step: 15700 Epoch 7/15 Iteration: 15700 Avg. Training loss: 3.3323 0.0069 sec/batch
# Global Step: 15800 Epoch 7/15 Iteration: 15800 Avg. Training loss: 3.3479 0.0069 sec/batch
# Global Step: 15900 Epoch 7/15 Iteration: 15900 Avg. Training loss: 3.3340 0.0060 sec/batch
# Global Step: 16000 Epoch 7/15 Iteration: 16000 Avg. Training loss: 3.3320 0.0062 sec/batch
# Global Step: 16100 Epoch 7/15 Iteration: 16100 Avg. Training loss: 3.3284 0.0060 sec/batch
# Global Step: 16200 Epoch 7/15 Iteration: 16200 Avg. Training loss: 3.3223 0.0070 sec/batch
# Global Step: 16300 Epoch 7/15 Iteration: 16300 Avg. Training loss: 3.3172 0.0079 sec/batch
# Global Step: 16400 Epoch 7/15 Iteration: 16400 Avg. Training loss: 3.3332 0.0107 sec/batch
# Global Step: 16500 Epoch 7/15 Iteration: 16500 Avg. Training loss: 3.3124 0.0064 sec/batch
# Global Step: 16600 Epoch 7/15 Iteration: 16600 Avg. Training loss: 3.3145 0.0084 sec/batch
# Global Step: 16700 Epoch 7/15 Iteration: 16700 Avg. Training loss: 3.2914 0.0090 sec/batch
# Global Step: 16800 Epoch 7/15 Iteration: 16800 Avg. Training loss: 3.2795 0.0066 sec/batch
# Global Step: 16900 Epoch 7/15 Iteration: 16900 Avg. Training loss: 3.2892 0.0083 sec/batch
# Global Step: 17000 Epoch 7/15 Iteration: 17000 Avg. Training loss: 3.2899 0.0084 sec/batch
# Epoch 8/15 Threshold: 0.08598846953005658 Length of Training words: 2422576
# Global Step: 17100 Epoch 8/15 Iteration: 17100 Avg. Training loss: 3.2962 0.0070 sec/batch
# Global Step: 17200 Epoch 8/15 Iteration: 17200 Avg. Training loss: 3.3211 0.0083 sec/batch
# Global Step: 17300 Epoch 8/15 Iteration: 17300 Avg. Training loss: 3.2951 0.0067 sec/batch
# Global Step: 17400 Epoch 8/15 Iteration: 17400 Avg. Training loss: 3.2819 0.0063 sec/batch
# Global Step: 17500 Epoch 8/15 Iteration: 17500 Avg. Training loss: 3.2746 0.0085 sec/batch
# Global Step: 17600 Epoch 8/15 Iteration: 17600 Avg. Training loss: 3.2725 0.0065 sec/batch
# Global Step: 17700 Epoch 8/15 Iteration: 17700 Avg. Training loss: 3.2765 0.0071 sec/batch
# Global Step: 17800 Epoch 8/15 Iteration: 17800 Avg. Training loss: 3.2774 0.0071 sec/batch
# Global Step: 17900 Epoch 8/15 Iteration: 17900 Avg. Training loss: 3.2668 0.0080 sec/batch
# Global Step: 18000 Epoch 8/15 Iteration: 18000 Avg. Training loss: 3.2639 0.0069 sec/batch
# Global Step: 18100 Epoch 8/15 Iteration: 18100 Avg. Training loss: 3.2445 0.0051 sec/batch
# Global Step: 18200 Epoch 8/15 Iteration: 18200 Avg. Training loss: 3.2555 0.0070 sec/batch
# Global Step: 18300 Epoch 8/15 Iteration: 18300 Avg. Training loss: 3.2588 0.0063 sec/batch
# Global Step: 18400 Epoch 8/15 Iteration: 18400 Avg. Training loss: 3.2609 0.0068 sec/batch
# Global Step: 18500 Epoch 8/15 Iteration: 18500 Avg. Training loss: 3.2510 0.0087 sec/batch
# Global Step: 18600 Epoch 8/15 Iteration: 18600 Avg. Training loss: 3.2509 0.0064 sec/batch
# Global Step: 18700 Epoch 8/15 Iteration: 18700 Avg. Training loss: 3.2349 0.0053 sec/batch
# Global Step: 18800 Epoch 8/15 Iteration: 18800 Avg. Training loss: 3.2621 0.0069 sec/batch
# Global Step: 18900 Epoch 8/15 Iteration: 18900 Avg. Training loss: 3.2431 0.0058 sec/batch
# Global Step: 19000 Epoch 8/15 Iteration: 19000 Avg. Training loss: 3.2546 0.0076 sec/batch
# Global Step: 19100 Epoch 8/15 Iteration: 19100 Avg. Training loss: 3.2290 0.0062 sec/batch
# Global Step: 19200 Epoch 8/15 Iteration: 19200 Avg. Training loss: 3.2164 0.0053 sec/batch
# Global Step: 19300 Epoch 8/15 Iteration: 19300 Avg. Training loss: 3.2381 0.0059 sec/batch
# Global Step: 19400 Epoch 8/15 Iteration: 19400 Avg. Training loss: 3.2255 0.0057 sec/batch
# Epoch 9/15 Threshold: 0.08102591917987945 Length of Training words: 2390581
# Global Step: 19500 Epoch 9/15 Iteration: 19500 Avg. Training loss: 3.2413 0.0044 sec/batch
# Global Step: 19600 Epoch 9/15 Iteration: 19600 Avg. Training loss: 3.2518 0.0060 sec/batch
# Global Step: 19700 Epoch 9/15 Iteration: 19700 Avg. Training loss: 3.2493 0.0051 sec/batch
# Global Step: 19800 Epoch 9/15 Iteration: 19800 Avg. Training loss: 3.2290 0.0056 sec/batch
# Global Step: 19900 Epoch 9/15 Iteration: 19900 Avg. Training loss: 3.2258 0.0060 sec/batch
# Global Step: 20000 Epoch 9/15 Iteration: 20000 Avg. Training loss: 3.2188 0.0054 sec/batch
# Global Step: 20100 Epoch 9/15 Iteration: 20100 Avg. Training loss: 3.2342 0.0062 sec/batch
# Global Step: 20200 Epoch 9/15 Iteration: 20200 Avg. Training loss: 3.2299 0.0053 sec/batch
# Global Step: 20300 Epoch 9/15 Iteration: 20300 Avg. Training loss: 3.2225 0.0087 sec/batch
# Global Step: 20400 Epoch 9/15 Iteration: 20400 Avg. Training loss: 3.2211 0.0065 sec/batch
# Global Step: 20500 Epoch 9/15 Iteration: 20500 Avg. Training loss: 3.2057 0.0077 sec/batch
# Global Step: 20600 Epoch 9/15 Iteration: 20600 Avg. Training loss: 3.2145 0.0064 sec/batch
# Global Step: 20700 Epoch 9/15 Iteration: 20700 Avg. Training loss: 3.2194 0.0070 sec/batch
# Global Step: 20800 Epoch 9/15 Iteration: 20800 Avg. Training loss: 3.2230 0.0109 sec/batch
# Global Step: 20900 Epoch 9/15 Iteration: 20900 Avg. Training loss: 3.2110 0.0066 sec/batch
# Global Step: 21000 Epoch 9/15 Iteration: 21000 Avg. Training loss: 3.2160 0.0076 sec/batch
# Global Step: 21100 Epoch 9/15 Iteration: 21100 Avg. Training loss: 3.2012 0.0053 sec/batch
# Global Step: 21200 Epoch 9/15 Iteration: 21200 Avg. Training loss: 3.2283 0.0057 sec/batch
# Global Step: 21300 Epoch 9/15 Iteration: 21300 Avg. Training loss: 3.2127 0.0066 sec/batch
# Global Step: 21400 Epoch 9/15 Iteration: 21400 Avg. Training loss: 3.2194 0.0067 sec/batch
# Global Step: 21500 Epoch 9/15 Iteration: 21500 Avg. Training loss: 3.1950 0.0088 sec/batch
# Global Step: 21600 Epoch 9/15 Iteration: 21600 Avg. Training loss: 3.1885 0.0069 sec/batch
# Global Step: 21700 Epoch 9/15 Iteration: 21700 Avg. Training loss: 3.2086 0.0078 sec/batch
# Global Step: 21800 Epoch 9/15 Iteration: 21800 Avg. Training loss: 3.1974 0.0061 sec/batch
# Epoch 10/15 Threshold: 0.09921773450911493 Length of Training words: 2494767
# Global Step: 21900 Epoch 10/15 Iteration: 21900 Avg. Training loss: 3.1997 0.0055 sec/batch
# Global Step: 22000 Epoch 10/15 Iteration: 22000 Avg. Training loss: 3.2065 0.0082 sec/batch
# Global Step: 22100 Epoch 10/15 Iteration: 22100 Avg. Training loss: 3.2023 0.0055 sec/batch
# Global Step: 22200 Epoch 10/15 Iteration: 22200 Avg. Training loss: 3.1835 0.0065 sec/batch
# Global Step: 22300 Epoch 10/15 Iteration: 22300 Avg. Training loss: 3.1803 0.0074 sec/batch
# Global Step: 22400 Epoch 10/15 Iteration: 22400 Avg. Training loss: 3.1773 0.0053 sec/batch
# Global Step: 22500 Epoch 10/15 Iteration: 22500 Avg. Training loss: 3.1922 0.0062 sec/batch
# Global Step: 22600 Epoch 10/15 Iteration: 22600 Avg. Training loss: 3.1844 0.0060 sec/batch
# Global Step: 22700 Epoch 10/15 Iteration: 22700 Avg. Training loss: 3.1713 0.0066 sec/batch
# Global Step: 22800 Epoch 10/15 Iteration: 22800 Avg. Training loss: 3.2002 0.0073 sec/batch
# Global Step: 22900 Epoch 10/15 Iteration: 22900 Avg. Training loss: 3.1657 0.0060 sec/batch
# Global Step: 23000 Epoch 10/15 Iteration: 23000 Avg. Training loss: 3.1658 0.0074 sec/batch
# Global Step: 23100 Epoch 10/15 Iteration: 23100 Avg. Training loss: 3.1871 0.0070 sec/batch
# Global Step: 23200 Epoch 10/15 Iteration: 23200 Avg. Training loss: 3.1726 0.0081 sec/batch
# Global Step: 23300 Epoch 10/15 Iteration: 23300 Avg. Training loss: 3.1782 0.0071 sec/batch
# Global Step: 23400 Epoch 10/15 Iteration: 23400 Avg. Training loss: 3.1791 0.0072 sec/batch
# Global Step: 23500 Epoch 10/15 Iteration: 23500 Avg. Training loss: 3.1717 0.0060 sec/batch
# Global Step: 23600 Epoch 10/15 Iteration: 23600 Avg. Training loss: 3.1726 0.0061 sec/batch
# Global Step: 23700 Epoch 10/15 Iteration: 23700 Avg. Training loss: 3.1966 0.0061 sec/batch
# Global Step: 23800 Epoch 10/15 Iteration: 23800 Avg. Training loss: 3.1763 0.0086 sec/batch
# Global Step: 23900 Epoch 10/15 Iteration: 23900 Avg. Training loss: 3.1822 0.0057 sec/batch
# Global Step: 24000 Epoch 10/15 Iteration: 24000 Avg. Training loss: 3.1620 0.0071 sec/batch
# Global Step: 24100 Epoch 10/15 Iteration: 24100 Avg. Training loss: 3.1542 0.0058 sec/batch
# Global Step: 24200 Epoch 10/15 Iteration: 24200 Avg. Training loss: 3.1683 0.0063 sec/batch
# Global Step: 24300 Epoch 10/15 Iteration: 24300 Avg. Training loss: 3.1685 0.0065 sec/batch
# Epoch 11/15 Threshold: 0.08003650813755342 Length of Training words: 2384875
# Global Step: 24400 Epoch 11/15 Iteration: 24400 Avg. Training loss: 3.1931 0.0048 sec/batch
# Global Step: 24500 Epoch 11/15 Iteration: 24500 Avg. Training loss: 3.2156 0.0080 sec/batch
# Global Step: 24600 Epoch 11/15 Iteration: 24600 Avg. Training loss: 3.2016 0.0061 sec/batch
# Global Step: 24700 Epoch 11/15 Iteration: 24700 Avg. Training loss: 3.1877 0.0053 sec/batch
# Global Step: 24800 Epoch 11/15 Iteration: 24800 Avg. Training loss: 3.1830 0.0057 sec/batch
# Global Step: 24900 Epoch 11/15 Iteration: 24900 Avg. Training loss: 3.1833 0.0055 sec/batch
# Global Step: 25000 Epoch 11/15 Iteration: 25000 Avg. Training loss: 3.1873 0.0073 sec/batch
# Global Step: 25100 Epoch 11/15 Iteration: 25100 Avg. Training loss: 3.1991 0.0063 sec/batch
# Global Step: 25200 Epoch 11/15 Iteration: 25200 Avg. Training loss: 3.1844 0.0057 sec/batch
# Global Step: 25300 Epoch 11/15 Iteration: 25300 Avg. Training loss: 3.1824 0.0059 sec/batch
# Global Step: 25400 Epoch 11/15 Iteration: 25400 Avg. Training loss: 3.1754 0.0062 sec/batch
# Global Step: 25500 Epoch 11/15 Iteration: 25500 Avg. Training loss: 3.1901 0.0069 sec/batch
# Global Step: 25600 Epoch 11/15 Iteration: 25600 Avg. Training loss: 3.1781 0.0073 sec/batch
# Global Step: 25700 Epoch 11/15 Iteration: 25700 Avg. Training loss: 3.1906 0.0063 sec/batch
# Global Step: 25800 Epoch 11/15 Iteration: 25800 Avg. Training loss: 3.1800 0.0059 sec/batch
# Global Step: 25900 Epoch 11/15 Iteration: 25900 Avg. Training loss: 3.1878 0.0095 sec/batch
# Global Step: 26000 Epoch 11/15 Iteration: 26000 Avg. Training loss: 3.1779 0.0092 sec/batch
# Global Step: 26100 Epoch 11/15 Iteration: 26100 Avg. Training loss: 3.2016 0.0060 sec/batch
# Global Step: 26200 Epoch 11/15 Iteration: 26200 Avg. Training loss: 3.1886 0.0051 sec/batch
# Global Step: 26300 Epoch 11/15 Iteration: 26300 Avg. Training loss: 3.1903 0.0064 sec/batch
# Global Step: 26400 Epoch 11/15 Iteration: 26400 Avg. Training loss: 3.1721 0.0065 sec/batch
# Global Step: 26500 Epoch 11/15 Iteration: 26500 Avg. Training loss: 3.1676 0.0076 sec/batch
# Global Step: 26600 Epoch 11/15 Iteration: 26600 Avg. Training loss: 3.1728 0.0068 sec/batch
# Epoch 12/15 Threshold: 0.09024232432343998 Length of Training words: 2447783
# Global Step: 26700 Epoch 12/15 Iteration: 26700 Avg. Training loss: 3.1773 0.0003 sec/batch
# Global Step: 26800 Epoch 12/15 Iteration: 26800 Avg. Training loss: 3.1910 0.0065 sec/batch
# Global Step: 26900 Epoch 12/15 Iteration: 26900 Avg. Training loss: 3.1971 0.0065 sec/batch
# Global Step: 27000 Epoch 12/15 Iteration: 27000 Avg. Training loss: 3.1814 0.0062 sec/batch
# Global Step: 27100 Epoch 12/15 Iteration: 27100 Avg. Training loss: 3.1675 0.0077 sec/batch
# Global Step: 27200 Epoch 12/15 Iteration: 27200 Avg. Training loss: 3.1706 0.0056 sec/batch
# Global Step: 27300 Epoch 12/15 Iteration: 27300 Avg. Training loss: 3.1692 0.0072 sec/batch
# Global Step: 27400 Epoch 12/15 Iteration: 27400 Avg. Training loss: 3.1732 0.0068 sec/batch
# Global Step: 27500 Epoch 12/15 Iteration: 27500 Avg. Training loss: 3.1796 0.0062 sec/batch
# Global Step: 27600 Epoch 12/15 Iteration: 27600 Avg. Training loss: 3.1705 0.0069 sec/batch
# Global Step: 27700 Epoch 12/15 Iteration: 27700 Avg. Training loss: 3.1707 0.0061 sec/batch
# Global Step: 27800 Epoch 12/15 Iteration: 27800 Avg. Training loss: 3.1559 0.0060 sec/batch
# Global Step: 27900 Epoch 12/15 Iteration: 27900 Avg. Training loss: 3.1667 0.0057 sec/batch
# Global Step: 28000 Epoch 12/15 Iteration: 28000 Avg. Training loss: 3.1743 0.0091 sec/batch
# Global Step: 28100 Epoch 12/15 Iteration: 28100 Avg. Training loss: 3.1807 0.0082 sec/batch
# Global Step: 28200 Epoch 12/15 Iteration: 28200 Avg. Training loss: 3.1689 0.0055 sec/batch
# Global Step: 28300 Epoch 12/15 Iteration: 28300 Avg. Training loss: 3.1694 0.0084 sec/batch
# Global Step: 28400 Epoch 12/15 Iteration: 28400 Avg. Training loss: 3.1606 0.0058 sec/batch
# Global Step: 28500 Epoch 12/15 Iteration: 28500 Avg. Training loss: 3.1849 0.0058 sec/batch
# Global Step: 28600 Epoch 12/15 Iteration: 28600 Avg. Training loss: 3.1787 0.0070 sec/batch
# Global Step: 28700 Epoch 12/15 Iteration: 28700 Avg. Training loss: 3.1841 0.0074 sec/batch
# Global Step: 28800 Epoch 12/15 Iteration: 28800 Avg. Training loss: 3.1643 0.0063 sec/batch
# Global Step: 28900 Epoch 12/15 Iteration: 28900 Avg. Training loss: 3.1540 0.0061 sec/batch
# Global Step: 29000 Epoch 12/15 Iteration: 29000 Avg. Training loss: 3.1717 0.0072 sec/batch
# Global Step: 29100 Epoch 12/15 Iteration: 29100 Avg. Training loss: 3.1618 0.0098 sec/batch
# Epoch 13/15 Threshold: 0.09189751048554491 Length of Training words: 2458283
# Global Step: 29200 Epoch 13/15 Iteration: 29200 Avg. Training loss: 3.1686 0.0040 sec/batch
# Global Step: 29300 Epoch 13/15 Iteration: 29300 Avg. Training loss: 3.1892 0.0084 sec/batch
# Global Step: 29400 Epoch 13/15 Iteration: 29400 Avg. Training loss: 3.1823 0.0059 sec/batch
# Global Step: 29500 Epoch 13/15 Iteration: 29500 Avg. Training loss: 3.1757 0.0050 sec/batch
# Global Step: 29600 Epoch 13/15 Iteration: 29600 Avg. Training loss: 3.1647 0.0056 sec/batch
# Global Step: 29700 Epoch 13/15 Iteration: 29700 Avg. Training loss: 3.1601 0.0077 sec/batch
# Global Step: 29800 Epoch 13/15 Iteration: 29800 Avg. Training loss: 3.1762 0.0060 sec/batch
# Global Step: 29900 Epoch 13/15 Iteration: 29900 Avg. Training loss: 3.1729 0.0062 sec/batch
# Global Step: 30000 Epoch 13/15 Iteration: 30000 Avg. Training loss: 3.1615 0.0126 sec/batch
# Global Step: 30100 Epoch 13/15 Iteration: 30100 Avg. Training loss: 3.1847 0.0063 sec/batch
# Global Step: 30200 Epoch 13/15 Iteration: 30200 Avg. Training loss: 3.1568 0.0068 sec/batch
# Global Step: 30300 Epoch 13/15 Iteration: 30300 Avg. Training loss: 3.1546 0.0085 sec/batch
# Global Step: 30400 Epoch 13/15 Iteration: 30400 Avg. Training loss: 3.1737 0.0063 sec/batch
# Global Step: 30500 Epoch 13/15 Iteration: 30500 Avg. Training loss: 3.1661 0.0067 sec/batch
# Global Step: 30600 Epoch 13/15 Iteration: 30600 Avg. Training loss: 3.1679 0.0078 sec/batch
# Global Step: 30700 Epoch 13/15 Iteration: 30700 Avg. Training loss: 3.1706 0.0090 sec/batch
# Global Step: 30800 Epoch 13/15 Iteration: 30800 Avg. Training loss: 3.1638 0.0084 sec/batch
# Global Step: 30900 Epoch 13/15 Iteration: 30900 Avg. Training loss: 3.1646 0.0055 sec/batch
# Global Step: 31000 Epoch 13/15 Iteration: 31000 Avg. Training loss: 3.1900 0.0059 sec/batch
# Global Step: 31100 Epoch 13/15 Iteration: 31100 Avg. Training loss: 3.1702 0.0056 sec/batch
# Global Step: 31200 Epoch 13/15 Iteration: 31200 Avg. Training loss: 3.1760 0.0071 sec/batch
# Global Step: 31300 Epoch 13/15 Iteration: 31300 Avg. Training loss: 3.1556 0.0063 sec/batch
# Global Step: 31400 Epoch 13/15 Iteration: 31400 Avg. Training loss: 3.1560 0.0073 sec/batch
# Global Step: 31500 Epoch 13/15 Iteration: 31500 Avg. Training loss: 3.1594 0.0070 sec/batch
# Global Step: 31600 Epoch 13/15 Iteration: 31600 Avg. Training loss: 3.1643 0.0057 sec/batch
# Epoch 14/15 Threshold: 0.09797424768331649 Length of Training words: 2489125
# Global Step: 31700 Epoch 14/15 Iteration: 31700 Avg. Training loss: 3.1729 0.0073 sec/batch
# Global Step: 31800 Epoch 14/15 Iteration: 31800 Avg. Training loss: 3.1942 0.0062 sec/batch
# Global Step: 31900 Epoch 14/15 Iteration: 31900 Avg. Training loss: 3.1730 0.0053 sec/batch
# Global Step: 32000 Epoch 14/15 Iteration: 32000 Avg. Training loss: 3.1642 0.0054 sec/batch
# Global Step: 32100 Epoch 14/15 Iteration: 32100 Avg. Training loss: 3.1579 0.0069 sec/batch
# Global Step: 32200 Epoch 14/15 Iteration: 32200 Avg. Training loss: 3.1580 0.0054 sec/batch
# Global Step: 32300 Epoch 14/15 Iteration: 32300 Avg. Training loss: 3.1692 0.0056 sec/batch
# Global Step: 32400 Epoch 14/15 Iteration: 32400 Avg. Training loss: 3.1688 0.0076 sec/batch
# Global Step: 32500 Epoch 14/15 Iteration: 32500 Avg. Training loss: 3.1620 0.0084 sec/batch
# Global Step: 32600 Epoch 14/15 Iteration: 32600 Avg. Training loss: 3.1676 0.0075 sec/batch
# Global Step: 32700 Epoch 14/15 Iteration: 32700 Avg. Training loss: 3.1519 0.0067 sec/batch
# Global Step: 32800 Epoch 14/15 Iteration: 32800 Avg. Training loss: 3.1596 0.0071 sec/batch
# Global Step: 32900 Epoch 14/15 Iteration: 32900 Avg. Training loss: 3.1723 0.0054 sec/batch
# Global Step: 33000 Epoch 14/15 Iteration: 33000 Avg. Training loss: 3.1532 0.0066 sec/batch
# Global Step: 33100 Epoch 14/15 Iteration: 33100 Avg. Training loss: 3.1731 0.0060 sec/batch
# Global Step: 33200 Epoch 14/15 Iteration: 33200 Avg. Training loss: 3.1569 0.0074 sec/batch
# Global Step: 33300 Epoch 14/15 Iteration: 33300 Avg. Training loss: 3.1472 0.0059 sec/batch
# Global Step: 33400 Epoch 14/15 Iteration: 33400 Avg. Training loss: 3.1773 0.0053 sec/batch
# Global Step: 33500 Epoch 14/15 Iteration: 33500 Avg. Training loss: 3.1785 0.0078 sec/batch
# Global Step: 33600 Epoch 14/15 Iteration: 33600 Avg. Training loss: 3.1693 0.0064 sec/batch
# Global Step: 33700 Epoch 14/15 Iteration: 33700 Avg. Training loss: 3.1684 0.0064 sec/batch
# Global Step: 33800 Epoch 14/15 Iteration: 33800 Avg. Training loss: 3.1518 0.0062 sec/batch
# Global Step: 33900 Epoch 14/15 Iteration: 33900 Avg. Training loss: 3.1454 0.0064 sec/batch
# Global Step: 34000 Epoch 14/15 Iteration: 34000 Avg. Training loss: 3.1571 0.0095 sec/batch
# Epoch 15/15 Threshold: 0.08922671053426086 Length of Training words: 2441840
# Global Step: 34100 Epoch 15/15 Iteration: 34100 Avg. Training loss: 3.1543 0.0005 sec/batch
# Global Step: 34200 Epoch 15/15 Iteration: 34200 Avg. Training loss: 3.1928 0.0055 sec/batch
# Global Step: 34300 Epoch 15/15 Iteration: 34300 Avg. Training loss: 3.1912 0.0061 sec/batch
# Global Step: 34400 Epoch 15/15 Iteration: 34400 Avg. Training loss: 3.1824 0.0069 sec/batch
# Global Step: 34500 Epoch 15/15 Iteration: 34500 Avg. Training loss: 3.1639 0.0055 sec/batch
# Global Step: 34600 Epoch 15/15 Iteration: 34600 Avg. Training loss: 3.1703 0.0058 sec/batch
# Global Step: 34700 Epoch 15/15 Iteration: 34700 Avg. Training loss: 3.1718 0.0050 sec/batch
# Global Step: 34800 Epoch 15/15 Iteration: 34800 Avg. Training loss: 3.1657 0.0059 sec/batch
# Global Step: 34900 Epoch 15/15 Iteration: 34900 Avg. Training loss: 3.1834 0.0066 sec/batch
# Global Step: 35000 Epoch 15/15 Iteration: 35000 Avg. Training loss: 3.1691 0.0077 sec/batch
# Global Step: 35100 Epoch 15/15 Iteration: 35100 Avg. Training loss: 3.1671 0.0058 sec/batch
# Global Step: 35200 Epoch 15/15 Iteration: 35200 Avg. Training loss: 3.1596 0.0065 sec/batch
# Global Step: 35300 Epoch 15/15 Iteration: 35300 Avg. Training loss: 3.1700 0.0077 sec/batch
# Global Step: 35400 Epoch 15/15 Iteration: 35400 Avg. Training loss: 3.1680 0.0056 sec/batch
# Global Step: 35500 Epoch 15/15 Iteration: 35500 Avg. Training loss: 3.1770 0.0065 sec/batch
# Global Step: 35600 Epoch 15/15 Iteration: 35600 Avg. Training loss: 3.1726 0.0080 sec/batch
# Global Step: 35700 Epoch 15/15 Iteration: 35700 Avg. Training loss: 3.1702 0.0052 sec/batch
# Global Step: 35800 Epoch 15/15 Iteration: 35800 Avg. Training loss: 3.1583 0.0055 sec/batch
# Global Step: 35900 Epoch 15/15 Iteration: 35900 Avg. Training loss: 3.1891 0.0065 sec/batch
# Global Step: 36000 Epoch 15/15 Iteration: 36000 Avg. Training loss: 3.1730 0.0080 sec/batch
# Global Step: 36100 Epoch 15/15 Iteration: 36100 Avg. Training loss: 3.1838 0.0083 sec/batch
# Global Step: 36200 Epoch 15/15 Iteration: 36200 Avg. Training loss: 3.1621 0.0069 sec/batch
# Global Step: 36300 Epoch 15/15 Iteration: 36300 Avg. Training loss: 3.1513 0.0050 sec/batch
# Global Step: 36400 Epoch 15/15 Iteration: 36400 Avg. Training loss: 3.1748 0.0055 sec/batch
# Global Step: 36500 Epoch 15/15 Iteration: 36500 Avg. Training loss: 3.1622 0.0069 sec/batch

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints/' + model_name))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/pos_weighted_25_2/pos.ckpt

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

viz_words = n_vocab
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

fig, ax = plt.subplots(figsize=(16, 16))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='blue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=1, xytext=(embed_tsne[idx, 0]+1.5, embed_tsne[idx, 1]+1.5), fontsize=12)
