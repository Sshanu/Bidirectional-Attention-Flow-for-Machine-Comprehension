# %%
import time
import numpy as np
import tensorflow as tf
import re
from collections import Counter
from time import sleep
import json
import random

with open('data/pos_train.json') as json_data:
    d = json.load(json_data)

text=[]
l=0

for i in d:
    for j in i:
        for k in j:
            text.append(k)

tt = []
for i in range(len(text)):
    if(text[i]!=''):
        tt.append(text[i])

text = tt

for i in range(len(text)):
    if(text[i]=='$'or text[i]=='PDT' or text[i]=='WP$' or text[i]=="SYM" or text[i]=='LS' or text[i]=='#' or text[i]=='UH'):
        text[i]='OTHER'
    

word_counts = Counter(text)

word_counts.most_common()
# Out:
# [('NN', 391092),
#  ('IN', 313428),
#  ('NNP', 286327),
#  ('DT', 246818),
#  ('JJ', 194522),
#  ('NNS', 150057),
#  (',', 138811),
#  ('.', 92716),
#  ('CC', 86433),
#  ('VBD', 83807),
#  ('CD', 77651),
#  ('RB', 71899),
#  ('VBN', 69596),
#  ('TO', 48800),
#  ('VBZ', 41862),
#  ('VB', 40118),
#  ('VBG', 35283),
#  (':', 34343),
#  ('VBP', 28324),
#  ('PRP', 24380),
#  ('FW', 22213),
#  ('PRP$', 18771),
#  ('POS', 14923),
#  ('WDT', 13756),
#  ("''", 13344),
#  ('``', 12561),
#  ('MD', 11441),
#  ('NNPS', 10637),
#  ('JJS', 6400),
#  ('JJR', 6373),
#  ('WRB', 5119),
#  ('WP', 4378),
#  ('RP', 3189),
#  ('RBR', 2910),
#  ('OTHER', 2645),
#  ('EX', 2623),
#  ('RBS', 2274)]

# %%
def create_lookup_tables(words):
    """
    Create lookup tables for vocabulary
    :param words: Input list of words
    :return: A tuple of dicts.  The first dict....
    """
    word_counts = Counter(words)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {ii: word for ii, word in enumerate(sorted_vocab)}
    vocab_to_int = {word: ii for ii, word in int_to_vocab.items()}

    return vocab_to_int, int_to_vocab

def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)


def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
words = text

print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))

# vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
vocab_to_int, int_to_vocab = create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

word_counts = Counter(int_words)
total_count = len(int_words)
weights = np.multiply(3, [1 - 4*count/total_count for word, count in word_counts.items()])
weights = np.power(weights, 3)
weights = weights.astype(np.float32)
# Out:
# Total words: 2609824
# Unique words: 37

# %%
weights
# Out:
# array([  1.73559093,   3.78805947,   4.77103329,   6.48822594,
#          9.33509541,  12.32697105,  13.17344189,  17.04783058,
#         17.62837601,  17.8748703 ,  18.46170044,  19.02149582,
#         19.24876404,  21.38349342,  22.12929916,  22.31946182,
#         22.85234833,  22.95692444,  23.63411903,  24.08500099,
#         24.33515739,  24.73604965,  25.18941498,  25.3279953 ,
#         25.37704086,  25.47042656,  25.60440254,  25.7008667 ,
#         26.21323204,  26.2165184 ,  26.36946869,  26.46012688,
#         26.60602951,  26.64034271,  26.67296219,  26.67567253,  26.71867371], dtype=float32)

# %%
def get_train_word():
    threshold = random.uniform(0.08, 0.1)
    word_counts = Counter(int_words)
    total_count = len(int_words)
    freqs = {word: count/total_count for word, count in word_counts.items()}
    p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
    train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]
    return train_words, threshold

# %%
batch_size = 1000
window_size = 5
n_vocab = len(int_to_vocab)
n_embedding =  20
starter_learning_rate = 0.0001
decay_steps = 2000
decay_rate = 0.96
lambda_l2 = 0.05

# %%
# with tf.device('/device:GPU:3'):

train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None], name='labels')

    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output
    embed_drop = tf.nn.dropout(embed, 0.8)

    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding)), name="softmax_w") # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab), name="softmax_bias") # create softmax biases here

    logits = tf.matmul(embed_drop, tf.transpose(softmax_w)) + softmax_b

    class_weight = tf.constant(weights)
    weighted_logits = logits * class_weight



    labels_one_hot = tf.one_hot(labels, n_vocab)

    tv_all = tf.trainable_variables()

    l2_loss = lambda_l2 * tf.reduce_sum([ tf.nn.l2_loss(v) for v in tv_all ])

    loss = tf.nn.softmax_cross_entropy_with_logits(labels=labels_one_hot, logits=weighted_logits)

    cost = tf.reduce_mean(loss) + l2_loss

    global_step = tf.Variable(0, trainable=False, name="global_step")

    learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, decay_steps, decay_rate)


    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost, global_step=global_step)

    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm

# %%
model_name = 'pos_XX_weighted_20_2'

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints/pos_XX_weighted_20_2
# Out:
# mkdir: cannot create directory ‘checkpoints/pos_XX_weighted_20_2’: File exists

# %%
epochs = 10

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    batch_loss = 0
    sess.run(tf.global_variables_initializer())
    
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints/'+ model_name))
    embed_mat = sess.run(embedding)
    
    for e in range(1, epochs+1):
        train_words, threshold = get_train_word()
        print("Epoch {}/{}".format(e, epochs), "Threshold: {}".format(threshold), "Length of Training words: {}".format(len(train_words)))
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            feed = {inputs: x,
                    labels: np.array(y)}
            global_steps, train_loss, _ = sess.run([global_step, cost, optimizer], feed_dict=feed)
            
            batch_loss += train_loss
            
            if iteration % 100== 0: 
                end = time.time()
                print("Global Step: {}".format(global_steps), "Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(batch_loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                batch_loss = 0
                start = time.time()
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/" + model_name + "/pos.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/pos_XX_weighted_20_2/pos.ckpt
# Epoch 1/10 Threshold: 0.08100582877411591 Length of Training words: 2392048
# Global Step: 24466 Epoch 1/10 Iteration: 100 Avg. Training loss: 3.1384 0.0341 sec/batch
# Global Step: 24566 Epoch 1/10 Iteration: 200 Avg. Training loss: 3.1457 0.0328 sec/batch
# Global Step: 24666 Epoch 1/10 Iteration: 300 Avg. Training loss: 3.1246 0.0327 sec/batch
# Global Step: 24766 Epoch 1/10 Iteration: 400 Avg. Training loss: 3.0984 0.0284 sec/batch
# Global Step: 24866 Epoch 1/10 Iteration: 500 Avg. Training loss: 3.1074 0.0271 sec/batch
# Global Step: 24966 Epoch 1/10 Iteration: 600 Avg. Training loss: 3.1060 0.0281 sec/batch
# Global Step: 25066 Epoch 1/10 Iteration: 700 Avg. Training loss: 3.0978 0.0287 sec/batch
# Global Step: 25166 Epoch 1/10 Iteration: 800 Avg. Training loss: 3.1115 0.0257 sec/batch
# Global Step: 25266 Epoch 1/10 Iteration: 900 Avg. Training loss: 3.0983 0.0254 sec/batch
# Global Step: 25366 Epoch 1/10 Iteration: 1000 Avg. Training loss: 3.0869 0.0246 sec/batch
# Global Step: 25466 Epoch 1/10 Iteration: 1100 Avg. Training loss: 3.0874 0.0243 sec/batch
# Global Step: 25566 Epoch 1/10 Iteration: 1200 Avg. Training loss: 3.0997 0.0294 sec/batch
# Global Step: 25666 Epoch 1/10 Iteration: 1300 Avg. Training loss: 3.0866 0.0243 sec/batch
# Global Step: 25766 Epoch 1/10 Iteration: 1400 Avg. Training loss: 3.0894 0.0247 sec/batch
# Global Step: 25866 Epoch 1/10 Iteration: 1500 Avg. Training loss: 3.0822 0.0248 sec/batch
# Global Step: 25966 Epoch 1/10 Iteration: 1600 Avg. Training loss: 3.0905 0.0242 sec/batch
# Global Step: 26066 Epoch 1/10 Iteration: 1700 Avg. Training loss: 3.0783 0.0245 sec/batch
# Global Step: 26166 Epoch 1/10 Iteration: 1800 Avg. Training loss: 3.1052 0.0247 sec/batch
# Global Step: 39966 Epoch 7/10 Iteration: 15600 Avg. Training loss: 3.0361 0.0277 sec/batch
# Global Step: 40066 Epoch 7/10 Iteration: 15700 Avg. Training loss: 3.0409 0.0339 sec/batch
# Global Step: 40166 Epoch 7/10 Iteration: 15800 Avg. Training loss: 3.0566 0.0555 sec/batch
# Global Step: 40266 Epoch 7/10 Iteration: 15900 Avg. Training loss: 3.0369 0.0490 sec/batch
# Global Step: 40366 Epoch 7/10 Iteration: 16000 Avg. Training loss: 3.0574 0.0478 sec/batch
# Global Step: 40466 Epoch 7/10 Iteration: 16100 Avg. Training loss: 3.0431 0.0352 sec/batch
# Global Step: 40566 Epoch 7/10 Iteration: 16200 Avg. Training loss: 3.0284 0.0310 sec/batch
# Global Step: 40666 Epoch 7/10 Iteration: 16300 Avg. Training loss: 3.0712 0.0275 sec/batch
# Global Step: 40766 Epoch 7/10 Iteration: 16400 Avg. Training loss: 3.0503 0.0266 sec/batch
# Global Step: 40866 Epoch 7/10 Iteration: 16500 Avg. Training loss: 3.0581 0.0275 sec/batch
# Global Step: 40966 Epoch 7/10 Iteration: 16600 Avg. Training loss: 3.0407 0.0257 sec/batch
# Global Step: 41066 Epoch 7/10 Iteration: 16700 Avg. Training loss: 3.0301 0.0259 sec/batch
# Global Step: 41166 Epoch 7/10 Iteration: 16800 Avg. Training loss: 3.0429 0.0256 sec/batch
# Global Step: 41266 Epoch 7/10 Iteration: 16900 Avg. Training loss: 3.0388 0.0265 sec/batch
# Epoch 8/10 Threshold: 0.08434213254765148 Length of Training words: 2412859
# Global Step: 41366 Epoch 8/10 Iteration: 17000 Avg. Training loss: 3.0474 0.0148 sec/batch
# Global Step: 41466 Epoch 8/10 Iteration: 17100 Avg. Training loss: 3.0715 0.0257 sec/batch
# Global Step: 41566 Epoch 8/10 Iteration: 17200 Avg. Training loss: 3.0656 0.0256 sec/batch
# Global Step: 41666 Epoch 8/10 Iteration: 17300 Avg. Training loss: 3.0566 0.0254 sec/batch
# Global Step: 41766 Epoch 8/10 Iteration: 17400 Avg. Training loss: 3.0443 0.0254 sec/batch
# Global Step: 41866 Epoch 8/10 Iteration: 17500 Avg. Training loss: 3.0333 0.0264 sec/batch
# Global Step: 41966 Epoch 8/10 Iteration: 17600 Avg. Training loss: 3.0626 0.0265 sec/batch
# Global Step: 42066 Epoch 8/10 Iteration: 17700 Avg. Training loss: 3.0513 0.0286 sec/batch
# Global Step: 42166 Epoch 8/10 Iteration: 17800 Avg. Training loss: 3.0351 0.0302 sec/batch
# Global Step: 42266 Epoch 8/10 Iteration: 17900 Avg. Training loss: 3.0666 0.0257 sec/batch
# Global Step: 42366 Epoch 8/10 Iteration: 18000 Avg. Training loss: 3.0345 0.0262 sec/batch
# Global Step: 42466 Epoch 8/10 Iteration: 18100 Avg. Training loss: 3.0376 0.0345 sec/batch
# Global Step: 42566 Epoch 8/10 Iteration: 18200 Avg. Training loss: 3.0615 0.0315 sec/batch
# Global Step: 48166 Epoch 10/10 Iteration: 23800 Avg. Training loss: 3.0377 0.0453 sec/batch
# Global Step: 48266 Epoch 10/10 Iteration: 23900 Avg. Training loss: 3.0403 0.0509 sec/batch
# Global Step: 48366 Epoch 10/10 Iteration: 24000 Avg. Training loss: 3.0206 0.0412 sec/batch
# Global Step: 48466 Epoch 10/10 Iteration: 24100 Avg. Training loss: 3.0173 0.0386 sec/batch
# Global Step: 48566 Epoch 10/10 Iteration: 24200 Avg. Training loss: 3.0224 0.0284 sec/batch
# Global Step: 48666 Epoch 10/10 Iteration: 24300 Avg. Training loss: 3.0286 0.0281 sec/batch

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints/' + model_name))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/pos_XX_weighted_20_2/pos.ckpt

# %%
embed_mat
# Out:
# array([[ -4.26619984e-02,  -3.71754952e-02,  -4.56537791e-02,
#          -1.06573375e-02,  -9.69499256e-03,   4.98746708e-02,
#          -7.47714611e-03,   1.97351426e-02,  -8.31906032e-03,
#           2.14837156e-02,   2.75342651e-02,  -2.03386620e-02,
#           3.05293035e-02,   1.78031269e-02,   1.51302172e-02,
#           9.18451406e-04,  -2.61369180e-02,   7.67677673e-04,
#          -9.29809269e-03,  -2.71304417e-03],
#        [ -1.14616016e-02,   7.10757542e-03,  -6.57383306e-03,
#          -6.72981702e-03,   1.95860937e-02,  -8.60861875e-03,
#          -4.33372241e-03,   1.91760510e-02,   9.96887125e-03,
#          -3.40657607e-02,  -1.55245736e-02,  -2.31320038e-02,
#           2.42336281e-02,  -2.67201886e-02,  -2.97327749e-02,
#          -9.33389738e-03,   1.01017323e-03,  -9.54142492e-03,
#           4.16467786e-02,   3.59817408e-03],
#        [ -1.52889974e-02,   2.85684969e-02,  -6.14560395e-03,
#           1.01446390e-01,   5.42838685e-02,   7.20162913e-02,
#           7.46079385e-02,   4.47097793e-02,  -8.95063654e-02,
#           4.10087928e-02,   4.87813875e-02,   3.67271267e-02,
#           7.41796382e-03,  -7.50913545e-02,   5.54180183e-02,
#           1.14325389e-01,  -5.23038656e-02,  -7.67427310e-02,
#           4.37078588e-02,   4.51840647e-02],
#        [ -1.59034468e-02,  -1.66808348e-02,  -1.83453169e-02,
#           1.78712234e-03,  -1.69163663e-02,   9.39883105e-03,
#          -6.57347636e-03,  -1.00883106e-02,  -3.99365230e-03,
#           3.12960222e-02,   2.29578372e-02,   2.83958055e-02,
#          -4.62652370e-03,   1.17911305e-02,   2.44161580e-02,
#           1.39887044e-02,  -8.77579115e-03,  -8.80147389e-04,
#          -1.21342773e-02,   3.10569704e-02],
#        [ -2.57623047e-02,  -2.80770995e-02,  -2.72868779e-02,
#          -2.68970504e-02,  -1.89200118e-02,   3.85749596e-03,
#          -2.32988540e-02,   2.30812584e-03,   1.59510877e-02,
#           3.58490250e-03,   6.92939106e-03,  -1.39602637e-02,
#           2.29392666e-02,   2.15458944e-02,  -3.66266910e-03,
#          -2.12794822e-03,   3.17202008e-04,   8.39946035e-04,
#           6.58450648e-04,   5.27957920e-04,   2.15802109e-04,
#          -6.38372498e-04,   1.41841499e-03],
#        [  8.86999711e-04,   3.43426327e-05,   8.04672833e-04,
#          -1.11269555e-03,  -1.33226521e-03,  -1.25205144e-03,
#          -1.17007131e-03,  -1.97414053e-03,   1.34957489e-03,
#           2.59745750e-04,  -4.60987852e-04,   1.41212402e-03,
#          -1.82283076e-03,   1.21374207e-03,   1.10233574e-04,
#          -9.33660427e-04,   1.09491986e-03,   1.22089975e-03,
#          -1.37456728e-03,   5.58810076e-04],
#        [  3.20254971e-04,  -1.70741536e-04,   5.02131879e-04,
#          -1.38676073e-03,  -1.44874083e-03,  -9.64873179e-04,
#          -1.12202868e-03,  -1.26504339e-03,   1.31176715e-03,
#           1.90711289e-05,  -3.56512668e-04,   5.27222757e-04,
#          -6.76239317e-04,   1.29073346e-03,  -2.66191695e-04,
#          -1.04060490e-03,   9.55069379e-04,   1.37884635e-03,
#          -1.30848004e-03,   3.46262823e-04],
#        [ -1.03065860e-04,   1.12683629e-04,  -9.66397492e-05,
#           6.72874565e-04,   7.84126110e-04,   2.29614816e-04,
#           5.86655573e-04,   5.28597098e-04,  -5.37005661e-04,
#          -2.01306728e-04,   5.91788594e-05,  -2.15736218e-04,
#           2.16477420e-04,  -6.07631751e-04,   5.33193015e-05,
#           5.84100431e-04,  -3.25059053e-04,  -5.04099822e-04,
#           5.61003515e-04,  -3.22307867e-04],
#        [ -6.91369351e-04,  -1.20394723e-03,  -1.15716853e-03,
#          -6.87763852e-04,  -1.05899200e-03,  -7.13381887e-05,
#          -9.51339491e-04,  -7.89621728e-04,   7.44359626e-04,
#           1.28133059e-03,   6.59371435e-04,   9.38594865e-04,
#          -1.59621952e-04,   1.20454223e-03,   7.37264927e-04,
#          -3.77548800e-04,  -4.55475601e-05,   6.94622635e-04,
#          -9.57857119e-04,   1.17250730e-03],
#        [ -8.88922950e-04,  -6.31935662e-04,  -5.81162050e-04,
#          -8.35065381e-04,  -3.48008791e-04,   2.26043252e-04,
#          -5.91271790e-04,   2.05617602e-04,   4.38393618e-04,
#           1.95284483e-05,   1.19213808e-04,  -3.56584176e-04,
#           5.93225472e-04,   4.72600776e-04,  -2.02952113e-04,
#          -7.09046260e-04,  -5.92277902e-05,   3.11217096e-04,
#          -1.09759276e-04,   2.24792617e-04]], dtype=float32)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

viz_words = n_vocab
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

fig, ax = plt.subplots(figsize=(16, 16))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='blue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=1, xytext=(embed_tsne[idx, 0]+1.5, embed_tsne[idx, 1]+1.5), fontsize=12)

# %%
embed_mat = embed_mat.tolist() # nested lists with same data, indices


with open('data/pos_embd.json', 'w') as fh:
    json.dump(embed_mat, fh)
