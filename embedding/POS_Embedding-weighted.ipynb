# %%
import time
import numpy as np
import tensorflow as tf
import re
from collections import Counter
from time import sleep
import json
import random

# %%
with open('data/pos_train.json') as json_data:
    d = json.load(json_data)

text=[]
l=0

for i in d:
    for j in i:
        for k in j:
            text.append(k)

tt = []
for i in range(len(text)):
    if(text[i]!=''):
        tt.append(text[i])

text = tt

for i in range(len(text)):
    if(text[i]=='$'or text[i]=='PDT' or text[i]=='WP$' or text[i]=="SYM" or text[i]=='LS' or text[i]=='#' or text[i]=='UH'):
        text[i]='OTHER'
    

word_counts = Counter(text)

word_counts.most_common()
# Out:
# [('NN', 391092),
#  ('IN', 313428),
#  ('NNP', 286327),
#  ('DT', 246818),
#  ('JJ', 194522),
#  ('NNS', 150057),
#  (',', 138811),
#  ('.', 92716),
#  ('CC', 86433),
#  ('VBD', 83807),
#  ('CD', 77651),
#  ('RB', 71899),
#  ('VBN', 69596),
#  ('TO', 48800),
#  ('VBZ', 41862),
#  ('VB', 40118),
#  ('VBG', 35283),
#  (':', 34343),
#  ('VBP', 28324),
#  ('PRP', 24380),
#  ('FW', 22213),
#  ('PRP$', 18771),
#  ('POS', 14923),
#  ('WDT', 13756),
#  ("''", 13344),
#  ('``', 12561),
#  ('MD', 11441),
#  ('NNPS', 10637),
#  ('JJS', 6400),
#  ('JJR', 6373),
#  ('WRB', 5119),
#  ('WP', 4378),
#  ('RP', 3189),
#  ('RBR', 2910),
#  ('OTHER', 2645),
#  ('EX', 2623),
#  ('RBS', 2274)]

# %%
def create_lookup_tables(words):
    """
    Create lookup tables for vocabulary
    :param words: Input list of words
    :return: A tuple of dicts.  The first dict....
    """
    word_counts = Counter(words)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {ii: word for ii, word in enumerate(sorted_vocab)}
    vocab_to_int = {word: ii for ii, word in int_to_vocab.items()}

    return vocab_to_int, int_to_vocab

def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)


def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
words = text

print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))

# vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
vocab_to_int, int_to_vocab = create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

word_counts = Counter(int_words)
total_count = len(int_words)
weights = [1 - 3*count/total_count for word, count in word_counts.items()]
# Out:
# Total words: 2609824
# Unique words: 37

# %%
def get_train_word():
    threshold = random.uniform(0.08, 0.1)
    word_counts = Counter(int_words)
    total_count = len(int_words)
    freqs = {word: count/total_count for word, count in word_counts.items()}
    p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
    train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]
    return train_words, threshold

# %%
batch_size = 1000
window_size = 5
n_vocab = len(int_to_vocab)
n_embedding =  50
starter_learning_rate = 0.001
decay_steps = 2000
decay_rate = 0.96
lambda_l2 = 0.01

# %%
with tf.device('/device:GPU:3'):

    train_graph = tf.Graph()
    with train_graph.as_default():
        inputs = tf.placeholder(tf.int32, [None], name='inputs')
        labels = tf.placeholder(tf.int32, [None], name='labels')

        embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
        embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output
        embed_drop = tf.nn.dropout(embed, 0.8)

        softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding)), name="softmax_w") # create softmax weight matrix here
        softmax_b = tf.Variable(tf.zeros(n_vocab), name="softmax_bias") # create softmax biases here

        logits = tf.matmul(embed_drop, tf.transpose(softmax_w)) + softmax_b
        
        class_weight = tf.constant(weights)
        weighted_logits = logits * class_weight


        
        labels_one_hot = tf.one_hot(labels, n_vocab)
        
        tv_all = tf.trainable_variables()

        l2_loss = lambda_l2 * tf.reduce_sum([ tf.nn.l2_loss(v) for v in tv_all ])

        loss = tf.nn.softmax_cross_entropy_with_logits(labels=labels_one_hot, logits=weighted_logits)
        
        cost = tf.reduce_mean(loss) + l2_loss
        
        global_step = tf.Variable(0, trainable=False, name="global_step")

        learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, decay_steps, decay_rate)


        optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost, global_step=global_step)
        
        norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
        normalized_embedding = embedding / norm

# %%
model_name = 'pos_weighted'

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints/pos_weighted
# Out:
# mkdir: cannot create directory ‘checkpoints/pos_weighted’: File exists

# %%
epochs = 10

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    batch_loss = 0
    sess.run(tf.global_variables_initializer())
    
#     saver.restore(sess, tf.train.latest_checkpoint('checkpoints/pos'))
#     embed_mat = sess.run(embedding)
    
    for e in range(1, epochs+1):
        train_words, threshold = get_train_word()
        print("Epoch {}/{}".format(e, epochs), "Threshold: {}".format(threshold), "Length of Training words: {}".format(len(train_words)))
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            feed = {inputs: x,
                    labels: np.array(y)}
            global_steps, train_loss, _ = sess.run([global_step, cost, optimizer], feed_dict=feed)
            
            batch_loss += train_loss
            
            if iteration % 100== 0: 
                end = time.time()
                print("Global Step: {}".format(global_steps), "Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(batch_loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                batch_loss = 0
                start = time.time()
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/" + model_name + "/pos.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Threshold: 0.0989152509918501 Length of Training words: 2493175
# Global Step: 100 Epoch 1/10 Iteration: 100 Avg. Training loss: 16.5563 0.0186 sec/batch
# Global Step: 200 Epoch 1/10 Iteration: 200 Avg. Training loss: 13.2500 0.0069 sec/batch
# Global Step: 300 Epoch 1/10 Iteration: 300 Avg. Training loss: 10.9316 0.0061 sec/batch
# Global Step: 400 Epoch 1/10 Iteration: 400 Avg. Training loss: 9.2860 0.0056 sec/batch
# Global Step: 500 Epoch 1/10 Iteration: 500 Avg. Training loss: 8.0463 0.0058 sec/batch
# Global Step: 600 Epoch 1/10 Iteration: 600 Avg. Training loss: 7.1054 0.0052 sec/batch
# Global Step: 700 Epoch 1/10 Iteration: 700 Avg. Training loss: 6.3774 0.0068 sec/batch
# Global Step: 800 Epoch 1/10 Iteration: 800 Avg. Training loss: 5.7983 0.0057 sec/batch
# Global Step: 900 Epoch 1/10 Iteration: 900 Avg. Training loss: 5.3257 0.0077 sec/batch
# Global Step: 1000 Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.9477 0.0073 sec/batch
# Global Step: 1100 Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.6236 0.0057 sec/batch
# Global Step: 1200 Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.3740 0.0067 sec/batch
# Global Step: 1300 Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.1810 0.0060 sec/batch
# Global Step: 1400 Epoch 1/10 Iteration: 1400 Avg. Training loss: 3.9921 0.0061 sec/batch
# Global Step: 1500 Epoch 1/10 Iteration: 1500 Avg. Training loss: 3.8697 0.0064 sec/batch
# Global Step: 1600 Epoch 1/10 Iteration: 1600 Avg. Training loss: 3.7416 0.0071 sec/batch
# Global Step: 1700 Epoch 1/10 Iteration: 1700 Avg. Training loss: 3.6338 0.0076 sec/batch
# Global Step: 1800 Epoch 1/10 Iteration: 1800 Avg. Training loss: 3.5870 0.0066 sec/batch
# Global Step: 1900 Epoch 1/10 Iteration: 1900 Avg. Training loss: 3.5191 0.0067 sec/batch
# Global Step: 2000 Epoch 1/10 Iteration: 2000 Avg. Training loss: 3.4581 0.0061 sec/batch
# Global Step: 2100 Epoch 1/10 Iteration: 2100 Avg. Training loss: 3.4145 0.0069 sec/batch
# Global Step: 2200 Epoch 1/10 Iteration: 2200 Avg. Training loss: 3.3627 0.0060 sec/batch
# Global Step: 2300 Epoch 1/10 Iteration: 2300 Avg. Training loss: 3.3340 0.0058 sec/batch
# Global Step: 2400 Epoch 1/10 Iteration: 2400 Avg. Training loss: 3.3133 0.0061 sec/batch
# Epoch 2/10 Threshold: 0.09198901919746016 Length of Training words: 2458566
# Global Step: 2500 Epoch 2/10 Iteration: 2500 Avg. Training loss: 3.2977 0.0005 sec/batch
# Global Step: 2600 Epoch 2/10 Iteration: 2600 Avg. Training loss: 3.3106 0.0074 sec/batch
# Global Step: 13900 Epoch 6/10 Iteration: 13900 Avg. Training loss: 3.2401 0.0064 sec/batch
# Global Step: 14000 Epoch 6/10 Iteration: 14000 Avg. Training loss: 3.2344 0.0086 sec/batch
# Global Step: 14100 Epoch 6/10 Iteration: 14100 Avg. Training loss: 3.2628 0.0057 sec/batch
# Global Step: 14200 Epoch 6/10 Iteration: 14200 Avg. Training loss: 3.2477 0.0075 sec/batch
# Global Step: 14300 Epoch 6/10 Iteration: 14300 Avg. Training loss: 3.2572 0.0069 sec/batch
# Global Step: 14400 Epoch 6/10 Iteration: 14400 Avg. Training loss: 3.2390 0.0078 sec/batch
# Global Step: 14500 Epoch 6/10 Iteration: 14500 Avg. Training loss: 3.2324 0.0064 sec/batch
# Global Step: 14600 Epoch 6/10 Iteration: 14600 Avg. Training loss: 3.2479 0.0095 sec/batch
# Global Step: 14700 Epoch 6/10 Iteration: 14700 Avg. Training loss: 3.2358 0.0058 sec/batch
# Epoch 7/10 Threshold: 0.08438851137016981 Length of Training words: 2412314
# Global Step: 14800 Epoch 7/10 Iteration: 14800 Avg. Training loss: 3.2473 0.0044 sec/batch
# Global Step: 14900 Epoch 7/10 Iteration: 14900 Avg. Training loss: 3.2585 0.0060 sec/batch
# Global Step: 15000 Epoch 7/10 Iteration: 15000 Avg. Training loss: 3.2607 0.0081 sec/batch
# Global Step: 15100 Epoch 7/10 Iteration: 15100 Avg. Training loss: 3.2463 0.0066 sec/batch
# Global Step: 15200 Epoch 7/10 Iteration: 15200 Avg. Training loss: 3.2402 0.0074 sec/batch
# Global Step: 15300 Epoch 7/10 Iteration: 15300 Avg. Training loss: 3.2371 0.0063 sec/batch
# Global Step: 15400 Epoch 7/10 Iteration: 15400 Avg. Training loss: 3.2527 0.0060 sec/batch
# Global Step: 15500 Epoch 7/10 Iteration: 15500 Avg. Training loss: 3.2473 0.0064 sec/batch
# Global Step: 15600 Epoch 7/10 Iteration: 15600 Avg. Training loss: 3.2381 0.0069 sec/batch
# Global Step: 15700 Epoch 7/10 Iteration: 15700 Avg. Training loss: 3.2547 0.0074 sec/batch
# Global Step: 15800 Epoch 7/10 Iteration: 15800 Avg. Training loss: 3.2335 0.0077 sec/batch
# Global Step: 15900 Epoch 7/10 Iteration: 15900 Avg. Training loss: 3.2385 0.0084 sec/batch
# Global Step: 16000 Epoch 7/10 Iteration: 16000 Avg. Training loss: 3.2516 0.0086 sec/batch
# Global Step: 16100 Epoch 7/10 Iteration: 16100 Avg. Training loss: 3.2374 0.0071 sec/batch
# Global Step: 16200 Epoch 7/10 Iteration: 16200 Avg. Training loss: 3.2525 0.0083 sec/batch
# Global Step: 16300 Epoch 7/10 Iteration: 16300 Avg. Training loss: 3.2412 0.0056 sec/batch
# Global Step: 16400 Epoch 7/10 Iteration: 16400 Avg. Training loss: 3.2301 0.0071 sec/batch
# Global Step: 16500 Epoch 7/10 Iteration: 16500 Avg. Training loss: 3.2611 0.0057 sec/batch
# Global Step: 16600 Epoch 7/10 Iteration: 16600 Avg. Training loss: 3.2457 0.0087 sec/batch
# Global Step: 16700 Epoch 7/10 Iteration: 16700 Avg. Training loss: 3.2533 0.0074 sec/batch
# Global Step: 16800 Epoch 7/10 Iteration: 16800 Avg. Training loss: 3.2411 0.0071 sec/batch
# Global Step: 16900 Epoch 7/10 Iteration: 16900 Avg. Training loss: 3.2369 0.0065 sec/batch
# Global Step: 17000 Epoch 7/10 Iteration: 17000 Avg. Training loss: 3.2414 0.0077 sec/batch
# Global Step: 17100 Epoch 7/10 Iteration: 17100 Avg. Training loss: 3.2381 0.0075 sec/batch
# Epoch 8/10 Threshold: 0.08425032824320168 Length of Training words: 2412093
# Global Step: 17200 Epoch 8/10 Iteration: 17200 Avg. Training loss: 3.2456 0.0041 sec/batch
# Global Step: 17300 Epoch 8/10 Iteration: 17300 Avg. Training loss: 3.2595 0.0059 sec/batch
# Global Step: 17400 Epoch 8/10 Iteration: 17400 Avg. Training loss: 3.2570 0.0092 sec/batch
# Global Step: 17500 Epoch 8/10 Iteration: 17500 Avg. Training loss: 3.2524 0.0064 sec/batch
# Global Step: 17600 Epoch 8/10 Iteration: 17600 Avg. Training loss: 3.2383 0.0075 sec/batch
# Global Step: 17700 Epoch 8/10 Iteration: 17700 Avg. Training loss: 3.2344 0.0058 sec/batch
# Global Step: 17800 Epoch 8/10 Iteration: 17800 Avg. Training loss: 3.2569 0.0068 sec/batch
# Global Step: 17900 Epoch 8/10 Iteration: 17900 Avg. Training loss: 3.2484 0.0070 sec/batch
# Global Step: 18000 Epoch 8/10 Iteration: 18000 Avg. Training loss: 3.2359 0.0077 sec/batch
# Global Step: 18100 Epoch 8/10 Iteration: 18100 Avg. Training loss: 3.2600 0.0092 sec/batch
# Global Step: 18200 Epoch 8/10 Iteration: 18200 Avg. Training loss: 3.2346 0.0067 sec/batch
# Global Step: 18300 Epoch 8/10 Iteration: 18300 Avg. Training loss: 3.2350 0.0081 sec/batch
# Global Step: 18400 Epoch 8/10 Iteration: 18400 Avg. Training loss: 3.2536 0.0060 sec/batch
# Global Step: 18500 Epoch 8/10 Iteration: 18500 Avg. Training loss: 3.2384 0.0076 sec/batch
# Global Step: 18600 Epoch 8/10 Iteration: 18600 Avg. Training loss: 3.2507 0.0058 sec/batch
# Global Step: 18700 Epoch 8/10 Iteration: 18700 Avg. Training loss: 3.2419 0.0068 sec/batch
# Global Step: 18800 Epoch 8/10 Iteration: 18800 Avg. Training loss: 3.2296 0.0076 sec/batch
# Global Step: 18900 Epoch 8/10 Iteration: 18900 Avg. Training loss: 3.2578 0.0080 sec/batch
# Global Step: 19000 Epoch 8/10 Iteration: 19000 Avg. Training loss: 3.2486 0.0062 sec/batch
# Global Step: 19100 Epoch 8/10 Iteration: 19100 Avg. Training loss: 3.2548 0.0087 sec/batch
# Global Step: 19200 Epoch 8/10 Iteration: 19200 Avg. Training loss: 3.2472 0.0074 sec/batch
# Global Step: 19300 Epoch 8/10 Iteration: 19300 Avg. Training loss: 3.2344 0.0085 sec/batch
# Global Step: 19400 Epoch 8/10 Iteration: 19400 Avg. Training loss: 3.2336 0.0062 sec/batch
# Global Step: 19500 Epoch 8/10 Iteration: 19500 Avg. Training loss: 3.2354 0.0082 sec/batch
# Epoch 9/10 Threshold: 0.09413046756851094 Length of Training words: 2471991
# Global Step: 19600 Epoch 9/10 Iteration: 19600 Avg. Training loss: 3.2443 0.0023 sec/batch
# Global Step: 19700 Epoch 9/10 Iteration: 19700 Avg. Training loss: 3.2417 0.0064 sec/batch
# Global Step: 19800 Epoch 9/10 Iteration: 19800 Avg. Training loss: 3.2555 0.0069 sec/batch
# Global Step: 19900 Epoch 9/10 Iteration: 19900 Avg. Training loss: 3.2454 0.0069 sec/batch
# Global Step: 20000 Epoch 9/10 Iteration: 20000 Avg. Training loss: 3.2309 0.0070 sec/batch
# Global Step: 20100 Epoch 9/10 Iteration: 20100 Avg. Training loss: 3.2294 0.0056 sec/batch
# Global Step: 20200 Epoch 9/10 Iteration: 20200 Avg. Training loss: 3.2309 0.0068 sec/batch
# Global Step: 20300 Epoch 9/10 Iteration: 20300 Avg. Training loss: 3.2357 0.0061 sec/batch
# Global Step: 20400 Epoch 9/10 Iteration: 20400 Avg. Training loss: 3.2383 0.0069 sec/batch
# Global Step: 20500 Epoch 9/10 Iteration: 20500 Avg. Training loss: 3.2446 0.0053 sec/batch
# Global Step: 20600 Epoch 9/10 Iteration: 20600 Avg. Training loss: 3.2238 0.0068 sec/batch
# Global Step: 20700 Epoch 9/10 Iteration: 20700 Avg. Training loss: 3.2262 0.0059 sec/batch
# Global Step: 20800 Epoch 9/10 Iteration: 20800 Avg. Training loss: 3.2392 0.0070 sec/batch
# Global Step: 20900 Epoch 9/10 Iteration: 20900 Avg. Training loss: 3.2304 0.0062 sec/batch
# Global Step: 21000 Epoch 9/10 Iteration: 21000 Avg. Training loss: 3.2361 0.0082 sec/batch
# Global Step: 21100 Epoch 9/10 Iteration: 21100 Avg. Training loss: 3.2301 0.0058 sec/batch
# Global Step: 21200 Epoch 9/10 Iteration: 21200 Avg. Training loss: 3.2404 0.0085 sec/batch
# Global Step: 21300 Epoch 9/10 Iteration: 21300 Avg. Training loss: 3.2234 0.0079 sec/batch
# Global Step: 21400 Epoch 9/10 Iteration: 21400 Avg. Training loss: 3.2527 0.0097 sec/batch
# Global Step: 21500 Epoch 9/10 Iteration: 21500 Avg. Training loss: 3.2351 0.0064 sec/batch
# Global Step: 21600 Epoch 9/10 Iteration: 21600 Avg. Training loss: 3.2443 0.0067 sec/batch
# Global Step: 21700 Epoch 9/10 Iteration: 21700 Avg. Training loss: 3.2241 0.0061 sec/batch
# Global Step: 21800 Epoch 9/10 Iteration: 21800 Avg. Training loss: 3.2192 0.0069 sec/batch
# Global Step: 21900 Epoch 9/10 Iteration: 21900 Avg. Training loss: 3.2404 0.0063 sec/batch
# Global Step: 22000 Epoch 9/10 Iteration: 22000 Avg. Training loss: 3.2263 0.0076 sec/batch
# Epoch 10/10 Threshold: 0.09236121086522461 Length of Training words: 2460653
# Global Step: 22100 Epoch 10/10 Iteration: 22100 Avg. Training loss: 3.2395 0.0042 sec/batch
# Global Step: 22200 Epoch 10/10 Iteration: 22200 Avg. Training loss: 3.2498 0.0080 sec/batch
# Global Step: 22300 Epoch 10/10 Iteration: 22300 Avg. Training loss: 3.2526 0.0059 sec/batch
# Global Step: 22400 Epoch 10/10 Iteration: 22400 Avg. Training loss: 3.2382 0.0063 sec/batch
# Global Step: 22500 Epoch 10/10 Iteration: 22500 Avg. Training loss: 3.2302 0.0067 sec/batch
# Global Step: 22600 Epoch 10/10 Iteration: 22600 Avg. Training loss: 3.2253 0.0056 sec/batch
# Global Step: 22700 Epoch 10/10 Iteration: 22700 Avg. Training loss: 3.2496 0.0076 sec/batch
# Global Step: 22800 Epoch 10/10 Iteration: 22800 Avg. Training loss: 3.2374 0.0062 sec/batch
# Global Step: 22900 Epoch 10/10 Iteration: 22900 Avg. Training loss: 3.2278 0.0072 sec/batch
# Global Step: 23000 Epoch 10/10 Iteration: 23000 Avg. Training loss: 3.2546 0.0059 sec/batch
# Global Step: 23100 Epoch 10/10 Iteration: 23100 Avg. Training loss: 3.2255 0.0080 sec/batch
# Global Step: 23200 Epoch 10/10 Iteration: 23200 Avg. Training loss: 3.2235 0.0060 sec/batch
# Global Step: 23300 Epoch 10/10 Iteration: 23300 Avg. Training loss: 3.2454 0.0070 sec/batch
# Global Step: 23400 Epoch 10/10 Iteration: 23400 Avg. Training loss: 3.2314 0.0059 sec/batch
# Global Step: 23500 Epoch 10/10 Iteration: 23500 Avg. Training loss: 3.2373 0.0068 sec/batch
# Global Step: 23600 Epoch 10/10 Iteration: 23600 Avg. Training loss: 3.2399 0.0074 sec/batch
# Global Step: 23700 Epoch 10/10 Iteration: 23700 Avg. Training loss: 3.2247 0.0080 sec/batch
# Global Step: 23800 Epoch 10/10 Iteration: 23800 Avg. Training loss: 3.2388 0.0072 sec/batch
# Global Step: 23900 Epoch 10/10 Iteration: 23900 Avg. Training loss: 3.2555 0.0078 sec/batch
# Global Step: 24000 Epoch 10/10 Iteration: 24000 Avg. Training loss: 3.2356 0.0074 sec/batch
# Global Step: 24100 Epoch 10/10 Iteration: 24100 Avg. Training loss: 3.2426 0.0070 sec/batch
# Global Step: 24200 Epoch 10/10 Iteration: 24200 Avg. Training loss: 3.2273 0.0061 sec/batch
# Global Step: 24300 Epoch 10/10 Iteration: 24300 Avg. Training loss: 3.2248 0.0067 sec/batch
# Global Step: 24400 Epoch 10/10 Iteration: 24400 Avg. Training loss: 3.2271 0.0078 sec/batch

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints/' + model_name))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/pos_weighted/pos.ckpt

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

viz_words = n_vocab
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

fig, ax = plt.subplots(figsize=(16, 16))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='blue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=1, xytext=(embed_tsne[idx, 0]+1.5, embed_tsne[idx, 1]+1.5), fontsize=12)
